# %%
import pandas as pd
import numpy as np
import re

# %%
# Folders:
folder_datafiles = '/mbshome/nvelthuijs/Cofactors/20200402_Transcriptionregulationlist/Datafiles/'
folder_corrected_names = '/mbshome/nvelthuijs/Cofactors/20200402_Transcriptionregulationlist/Datafiles_corrected_names/'
folder_output = '/mbshome/nvelthuijs/Cofactors/20200402_Transcriptionregulationlist/Output_files/'

# Files:
biogrid_file = folder_corrected_names + 'biogrid_corrected_names.txt'
tf_file = folder_datafiles + 'tfs.txt'
tf_smallset_file = folder_datafiles + 'tfs_smallset.txt'
intact_file = folder_datafiles + 'intact.txt'

# hugo_uniprot_file = '/mbshome/nvelthuijs/Cofactors/List2/Datafiles/HUGO_to_uniprot.txt'
hugo_translate_file = folder_datafiles + 'hugo_ensg_uniprot_approved.txt'

# %%
# Create set of tfs:
with open(tf_file) as tf_txt:
    tfs = set([tf.strip() for tf in tf_txt])

# Read biogrid into pandas dataframe:
with open(biogrid_file) as biogrid_full:
    biogrid = pd.read_table(biogrid_full,
                            usecols = ['#BioGRID Interaction ID',
                                       'Official Symbol Interactor A',
                                      'Official Symbol Interactor B',
                                      'Publication Source',
                                      'Organism Interactor A',
                                      'Organism Interactor B'],
                            dtype = str)
biogrid.columns = ['Int_ID', 'A', 'B', 'PMID', 'Org_A', 'Org_B']

# Filter out only human-human interactions,
# at least one of which is in the set of TFs.
biogrid = biogrid.loc[((biogrid['Org_A'] == '9606') & (biogrid['Org_B'] == '9606'))
                      & (biogrid['A'].isin(tfs) | biogrid['B'].isin(tfs))].drop(columns = ['Org_A', 'Org_B'])

# Create new dataframe with only columns A, B,
# interaction ID and PMID. For each row protein
# A and protein B are sorted alphabetticaly.
new_rows = []
for index, row in biogrid.iterrows():
    a = biogrid.loc[index, 'A']
    b = biogrid.loc[index, 'B']
    int_id = biogrid.loc[index, 'Int_ID']
    pmid = biogrid.loc[index, 'PMID']
    if a > b:
        new_rows.append([b, a, int_id, pmid])
    else:
        new_rows.append([a, b, int_id, pmid])
biogrid = pd.DataFrame(new_rows, columns = ['A', 'B', 'Int_ID', 'PMID'])#.reset_index(drop = True) #Do we need the reset_index?

# Create seperate dataframes depending on whether
# A or B is a TF. Group duplicate entries and count
# the number of PMIDs for each interaction, then
# only keep the ones with at least 2 references.
biogrid_a_tf = biogrid.loc[biogrid['A'].isin(tfs)].copy()
biogrid_a_tf_copy = biogrid_a_tf.groupby(['A', 'B']).nunique()
biogrid_a_tf_copy = biogrid_a_tf_copy.loc[biogrid_a_tf_copy['PMID'] > 1].copy()
biogrid_b_tf = biogrid.loc[biogrid['B'].isin(tfs)].copy()
biogrid_b_tf_copy = biogrid_b_tf.groupby(['A', 'B']).nunique()
biogrid_b_tf_copy = biogrid_b_tf_copy.loc[biogrid_b_tf_copy['PMID'] > 1].copy()

# Write interaction pairs to lists.
tf_int_list_a = [[index[0], index[1]] for index, row in biogrid_a_tf_copy.iterrows()]
tf_int_list_b = [[index[0], index[1]] for index, row in biogrid_b_tf_copy.iterrows()]

# Create interaction dictionary where each interactor is a key
# and the value is a list of all tfs it interacts with. Each TF
# is itself a list, containing the TF, the PMIDs and interaction IDs.
int_dict = {}
for i in tf_int_list_a:
    tf = i[0]
    interactor = i[1]
    df = biogrid_a_tf.loc[(biogrid_a_tf['A'] == tf) & (biogrid_a_tf['B'] == interactor)]
    pmids = [str(x) for x in set(df['PMID'])]
    newlist = [tf, ', '.join(pmids), set(df['Int_ID'])]
    if not interactor in int_dict.keys():
        int_dict[interactor] = [newlist]
    else:
        int_dict[interactor].append(newlist)

for i in tf_int_list_b:
    tf = i[1]
    interactor = i[0]
    df = biogrid_b_tf.loc[(biogrid_b_tf['B'] == tf) & (biogrid_b_tf['A'] == interactor)]
    pmids = [str(x) for x in set(df['PMID'])]
    newlist = [tf, ', '.join(pmids), set(df['Int_ID'])]
    if not interactor in int_dict.keys():
        int_dict[interactor] = [newlist]
    else:
        int_dict[interactor].append(newlist)

# Create a dataframe where each row is consists of
# interactor, tf, pmids and interaction IDs.
constructlist = []
for interactor, interactions in int_dict.items():
    for interaction in interactions:
        tf, pmids, int_ids = (interaction[i] for i in range(len(interaction)))
        constructlist.append([interactor, tf, pmids, int_ids])

interactors_biogrid = pd.DataFrame(constructlist, columns = ['Interactor', 'TF', 'PMIDS', 'Interaction IDs'])#.set_index('Interactor')
interactors_biogrid = interactors_biogrid.drop(columns = 'Interaction IDs').sort_values(by = ['Interactor', 'TF'])

# Create dataframe where each row has an interactor in the first
# collumn and all interacting tfs in the second:
biogrid_interactors = set(interactors_biogrid['Interactor'])
newrows = []
for interactor in biogrid_interactors:
    df = interactors_biogrid.loc[interactors_biogrid['Interactor'] == interactor]
    interacting_tfs = list(df['TF'])
    newrow = [interactor, ', '.join(interacting_tfs)]
    newrows.append(newrow)
interactors_biogrid_simple = pd.DataFrame(newrows, columns = ['Interactor', 'TFs'])
interactors_biogrid_simple = interactors_biogrid_simple.sort_values(by = ['Interactor', 'TFs'])

with open(tf_smallset_file) as tfs_small:
    tfs_small_set = set([x.strip() for x in tfs_small])
    new_col = []
    for index, row in interactors_biogrid_simple.iterrows():
        tfs_current = row['TFs'].split(', ')
        
        if any(x in tfs_small_set for x in tfs_current):
            new_col.append(1)
        else:
            new_col.append(0)
    interactors_biogrid_simple['Interaction with small set of TFs'] = new_col
    
# Write both dataframes to a .csv file:
interactors_biogrid.to_csv(folder_output + '02_tf_interactors_biogrid.csv', index = False)
interactors_biogrid_simple.to_csv(folder_output + '03_tf_interactors_biogrid_simple.csv', index = False)

print(len(biogrid_interactors))
print(interactors_biogrid.head(20))
print('\n')
print(interactors_biogrid_simple.head(20))
interactors_biogrid_simple
# Out:
# 2260
#      Interactor       TF                                              PMIDS
# 3932      AANAT  BHLHE40                   PUBMED:25416956, PUBMED:25910212
# 3933       AAR2      MYC                   PUBMED:30415952, PUBMED:29467282
# 3934       AATF      MYC                   PUBMED:30415952, PUBMED:29467282
# 3935      ABCA1    NR1H2                   PUBMED:25838426, PUBMED:20951680
# 3936       ABI1     LHX4                   PUBMED:28514442, PUBMED:26186194
# 3937       ABI1   ZNF511                   PUBMED:28514442, PUBMED:26186194
# 3938       ABI2     LHX4                   PUBMED:28514442, PUBMED:26186194
# 3939       ABI2   ZNF511                   PUBMED:28514442, PUBMED:26186194
# 3940       ABL1      JUN                   PUBMED:18619508, PUBMED:19818398
# 3941       ABL1     TP73  PUBMED:19442657, PUBMED:25893286, PUBMED:10391...
# 3942   ABRAXAS2   THAP11                   PUBMED:28514442, PUBMED:26186194
# 3943   ABRAXAS2     TP53  PUBMED:28514442, PUBMED:26186194, PUBMED:25283148
# 3944      ACOT1   TFAP2A                   PUBMED:28514442, PUBMED:26186194
# 3945      ACOX1    FOXS1                   PUBMED:28514442, PUBMED:26186194
# 3946       ACTB      ERG                   PUBMED:21575865, PUBMED:24591637
# 3947       ACTB     ESR1  PUBMED:20348541, PUBMED:20308691, PUBMED:21182205
# 3948       ACTB     ESR2                   PUBMED:21951318, PUBMED:21182203
# 3949       ACTB    LMX1B                   PUBMED:28514442, PUBMED:26186194
# 3950       ACTB      MYC                   PUBMED:11839798, PUBMED:29467282
# 3951       ACTB     TP53                   PUBMED:25144556, PUBMED:23443559
#
#
#      Interactor                                TFs  \
# 1793      AANAT                            BHLHE40
# 155        AAR2                                MYC
# 2171       AATF                                MYC
# 1010      ABCA1                              NR1H2
# 95         ABI1                       LHX4, ZNF511
# 1007       ABI2                       LHX4, ZNF511
# 2027       ABL1                          JUN, TP73
# 1684   ABRAXAS2                       THAP11, TP53
# 1019      ACOT1                             TFAP2A
# 1385      ACOX1                              FOXS1
# 186        ACTB  ERG, ESR1, ESR2, LMX1B, MYC, TP53
# 695       ACTC1                               ESR1
# 1751     ACTL6A                           MYC, YY1
# 1676      ACTN2                              SP100
# 99        ACTR2                               ESR1
# 1595      ACTR3                               ESR1
# 1905      ACTR5                                YY1
# 799       ACTR8                                YY1
# 126       ACVR1                       SMAD1, SMAD5
# 999    ADAMTS12                         USF1, USF2
#
#       Interaction with small set of TFs
# 1793                                  1
# 155                                   1
# 2171                                  1
# 1010                                  1
# 95                                    1
# 1007                                  1
# 2027                                  1
# 1684                                  1
# 1019                                  1
# 1385                                  1
# 186                                   1
# 695                                   1
# 1751                                  1
# 1676                                  1
# 99                                    1
# 1595                                  1
# 1905                                  1
# 799                                   1
# 126                                   1
# 999                                   1
#      Interactor                                                TFs  \
# 1793      AANAT                                            BHLHE40
# 155        AAR2                                                MYC
# 2171       AATF                                                MYC
# 1010      ABCA1                                              NR1H2
# 95         ABI1                                       LHX4, ZNF511
# 1007       ABI2                                       LHX4, ZNF511
# 2027       ABL1                                          JUN, TP73
# 1684   ABRAXAS2                                       THAP11, TP53
# 1019      ACOT1                                             TFAP2A
# 1385      ACOX1                                              FOXS1
# 186        ACTB                  ERG, ESR1, ESR2, LMX1B, MYC, TP53
# 695       ACTC1                                               ESR1
# 1751     ACTL6A                                           MYC, YY1
# 1676      ACTN2                                              SP100
# 99        ACTR2                                               ESR1
# 1595      ACTR3                                               ESR1
# 1905      ACTR5                                                YY1
# 799       ACTR8                                                YY1
# 126       ACVR1                                       SMAD1, SMAD5
# 999    ADAMTS12                                         USF1, USF2
# 824        ADAR                                                MYC
# 2157       ADNP                               MYC, ZNF524, ZSCAN20
# 1473       AGO1                                               TP53
# 1769       AGRN                                              ZFP41
# 124      AGTRAP                                               PBX3
# 378      AHCYL1                               HOXC9, PITX2, ZNF444
# 611      AHCYL2                         HOXC9, PITX2, VSX2, ZNF444
# 1120        AHR                            ARNT, ESR1, NR2F1, RELA
# 1254      AIMP2                                              ZGPAT
# 860         AIP                                                AHR
# ...         ...                                                ...
# 1818     ZNF536                                               SOX2
# 205      ZNF561                                             ZNF562
# 1804     ZNF562                                             ZNF561
# 1135     ZNF574                                               LHX4
# 2248     ZNF579                                             ZNF707
# 320      ZNF589                                               RBPJ
# 1250     ZNF624                                              ZNF22
# 1411     ZNF689                                     ZBTB38, ZNF707
# 867      ZNF703                                  HOXA1, MSX2, VSX2
# 846      ZNF707  RBAK, ZNF273, ZNF316, ZNF324, ZNF445, ZNF579, ...
# 708      ZNF746                                             ZNF212
# 444      ZNF747                                             ZNF707
# 1603     ZNF808                                              ZNF22
# 437       ZNF92                                             ZNF707
# 2053     ZNHIT3                                              PPARG
# 478       ZPBP2                                             ZNF146
# 1779     ZSCAN1  MZF1, PGBD1, ZNF174, ZNF213, ZNF24, ZNF496, ZS...
# 56      ZSCAN12                                            ZKSCAN7
# 356     ZSCAN16                                    ZNF446, ZSCAN32
# 1273    ZSCAN18                   ZNF396, ZSCAN1, ZSCAN20, ZSCAN32
# 1359    ZSCAN20  ADNP, PGBD1, ZKSCAN1, ZKSCAN3, ZKSCAN4, ZKSCAN...
# 1786    ZSCAN21                           ZNF397, ZSCAN20, ZSCAN32
# 1780    ZSCAN22                            PGBD1, ZSCAN20, ZSCAN32
# 760     ZSCAN23                                   ZSCAN20, ZSCAN32
# 119     ZSCAN25                                    ZSCAN1, ZSCAN20
# 1896    ZSCAN29                                            ZSCAN20
# 1172    ZSCAN30                   ZNF397, ZNF444, ZSCAN20, ZSCAN32
# 1230    ZSCAN32  PGBD1, ZKSCAN1, ZKSCAN3, ZKSCAN4, ZKSCAN8, ZNF...
# 1743     ZSCAN9                                             ZNF446
# 1527      ZZEF1                                              FOSL2
#
#       Interaction with small set of TFs
# 1793                                  1
# 155                                   1
# 2171                                  1
# 1010                                  1
# 95                                    1
# 1007                                  1
# 2027                                  1
# 1684                                  1
# 1019                                  1
# 1385                                  1
# 186                                   1
# 695                                   1
# 1751                                  1
# 1676                                  1
# 99                                    1
# 1595                                  1
# 1905                                  1
# 799                                   1
# 126                                   1
# 999                                   1
# 824                                   1
# 2157                                  1
# 1473                                  1
# 1769                                  1
# 124                                   1
# 378                                   1
# 611                                   1
# 1120                                  1
# 1254                                  1
# 860                                   1
# ...                                 ...
# 1818                                  1
# 205                                   0
# 1804                                  0
# 1135                                  1
# 2248                                  0
# 320                                   1
# 1250                                  0
# 1411                                  1
# 867                                   1
# 846                                   1
# 708                                   0
# 444                                   0
# 1603                                  0
# 437                                   0
# 2053                                  1
# 478                                   0
# 1779                                  1
# 56                                    1
# 356                                   1
# 1273                                  1
# 1359                                  1
# 1786                                  1
# 1780                                  1
# 760                                   1
# 119                                   1
# 1896                                  1
# 1172                                  1
# 1230                                  1
# 1743                                  1
# 1527                                  1
#
# [2260 rows x 3 columns]

# %%
# Create dictionary for translating
# UniProtIDs to gene names:
hugo_uniprot_dict = {}
with open(hugo_translate_file) as hugo_translate:
    next(hugo_translate)
    for line in hugo_translate:
        line = line.strip().split('\t')
        if len(line) >= 3:
            gene_name = line[0]
            uniprot_ids = line[2]
            if not ',' in uniprot_ids:
                hugo_uniprot_dict[uniprot_ids] = gene_name
            else:
                uniprot_ids = uniprot_ids.split(', ')
                for single_id in uniprot_ids:
                    hugo_uniprot_dict[single_id] = gene_name
hugo_uniprot_dict.pop('')
                    
for item in hugo_uniprot_dict.items():
    print(item)
# Out:
# ('P04217', 'A1BG')
# ('Q9NQ94', 'A1CF')
# ('P01023', 'A2M')
# ('A8K2U0', 'A2ML1')
# ('U3KPV4', 'A3GALT2')
# ('Q9NPC4', 'A4GALT')
# ('Q9UNA3', 'A4GNT')
# ('Q9NRG9', 'AAAS')
# ('Q86V21', 'AACS')
# ('P22760', 'AADAC')
# ('Q6P093', 'AADACL2')
# ('Q5VUY0', 'AADACL3')
# ('Q5VUY2', 'AADACL4')
# ('Q8N5Z0', 'AADAT')
# ('Q6PD74', 'AAGAB')
# ('Q2M2I8', 'AAK1')
# ('Q9H7C9', 'AAMDC')
# ('Q13685', 'AAMP')
# ('Q16613', 'AANAT')
# ('Q9Y312', 'AAR2')
# ('Q4LEZ3', 'AARD')
# ('P49588', 'AARS1')
# ('Q5JTZ9', 'AARS2')
# ('Q9BTE6', 'PTGES3L-AARSD1')
# ('Q4L235', 'AASDH')
# ('Q9NRN7', 'AASDHPPT')
# ('Q9UDR5', 'AASS')
# ('Q9NY61', 'AATF')
# ('Q6ZMQ8', 'AATK')
# ('P80404', 'ABAT')
# ('O95477', 'ABCA1')
# ('Q9BZC7', 'ABCA2')
# ('Q99758', 'ABCA3')
# ('P78363', 'ABCA4')
# ('Q8WWZ7', 'ABCA5')
# ('Q8N139', 'ABCA6')
# ('Q8IZY2', 'ABCA7')
# ('O94911', 'ABCA8')
# ('Q8IUA7', 'ABCA9')
# ('Q8WWZ4', 'ABCA10')
# ('Q4W5N1', 'ABCA11P')
# ('Q86UK0', 'ABCA12')
# ('Q86UQ4', 'ABCA13')
# ('P08183', 'ABCB1')
# ('P21439', 'ABCB4')
# ('Q2M3G0', 'ABCB5')
# ('Q9NP58', 'ABCB6')
# ('O75027', 'ABCB7')
# ('Q9NUT2', 'ABCB8')
# ('Q9NP78', 'ABCB9')
# ('Q9NRK6', 'ABCB10')
# ('O95342', 'ABCB11')
# ('P33527', 'ABCC1')
# ('Q92887', 'ABCC2')
# ('O15438', 'ABCC3')
# ('O15439', 'ABCC4')
# ('O15440', 'ABCC5')
# ('O95255', 'ABCC6')
# ('Q09428', 'ABCC8')
# ('O60706', 'ABCC9')
# ('Q5T3U5', 'ABCC10')
# ('Q96J66', 'ABCC11')
# ('Q96J65', 'ABCC12')
# ('P33897', 'ABCD1')
# ('Q9UBJ2', 'ABCD2')
# ('P28288', 'ABCD3')
# ('O14678', 'ABCD4')
# ('P61221', 'ABCE1')
# ('Q8NE71', 'ABCF1')
# ('Q9UG63', 'ABCF2')
# ('Q9NUQ8', 'ABCF3')
# ('P45844', 'ABCG1')
# ('Q9UNQ0', 'ABCG2')
# ('Q9H172', 'ABCG4')
# ('Q9H222', 'ABCG5')
# ('Q9H221', 'ABCG8')
# ('Q96SE0', 'ABHD1')
# ('P08910', 'ABHD2')
# ('Q8WU67', 'ABHD3')
# ('Q8TB40', 'ABHD4')
# ('Q8WTS1', 'ABHD5')
# ('Q9BV23', 'ABHD6')
# ('Q96I13', 'ABHD8')
# ('Q9NUJ1', 'ABHD10')
# ('Q8NFV4', 'ABHD11')
# ('Q8N2K0', 'ABHD12')
# ('Q7Z5M8', 'ABHD12B')
# ('Q7L211', 'ABHD13')
# ('Q9BUJ0', 'ABHD14A')
# ('Q96IU4', 'ABHD14B')
# ('Q6UXT9', 'ABHD15')
# ('O95870', 'ABHD16A')
# ('Q9H3Z7', 'ABHD16B')
# ('Q96GS6', 'ABHD17A')
# ('Q5VST6', 'ABHD17B')
# ('Q6PCB6', 'ABHD17C')
# ('Q0P651', 'ABHD18')
# ('Q8IZP0', 'ABI1')
# ('Q9NYB9', 'ABI2')
# ('Q9P2A4', 'ABI3')
# ('Q7Z7G0', 'ABI3BP')
# ('Q9NX38', 'ABITRAM')
# ('P00519', 'ABL1')
# ('P42684', 'ABL2')
# ('O14639', 'ABLIM1')
# ('Q6H8Q1', 'ABLIM2')
# ('O94929', 'ABLIM3')
# ('P16442', 'ABO')
# ('Q12979', 'ABR')
# ('Q8N0Z2', 'ABRA')
# ('Q9P1F3', 'ABRACL')
# ('Q6UWZ7', 'ABRAXAS1')
# ('Q15018', 'ABRAXAS2')
# ('Q9ULW3', 'ABT1')
# ('Q969K4', 'ABTB1')
# ('Q8N961', 'ABTB2')
# ('P09110', 'ACAA1')
# ('P42765', 'ACAA2')
# ('Q13085', 'ACACA')
# ('O00763', 'ACACB')
# ('Q9UKU7', 'ACAD8')
# ('Q9H845', 'ACAD9')
# ('Q6JQN1', 'ACAD10')
# ('Q709F0', 'ACAD11')
# ('P28330', 'ACADL')
# ('P11310', 'ACADM')
# ('P16219', 'ACADS')
# ('P45954', 'ACADSB')
# ('P49748', 'ACADVL')
# ('P16112', 'ACAN')
# ('Q15027', 'ACAP1')
# ('Q15057', 'ACAP2')
# ('Q96P50', 'ACAP3')
# ('P24752', 'ACAT1')
# ('Q9BWD1', 'ACAT2')
# ('Q9H3P7', 'ACBD3')
# ('Q8NC06', 'ACBD4')
# ('Q5T8D3', 'ACBD5')
# ('Q9BR61', 'ACBD6')
# ('Q8N6N7', 'ACBD7')
# ('Q96QU6', 'ACCS')
# ('Q4AC99', 'ACCSL')
# ('Q96AP0', 'ACD')
# ('P12821', 'ACE')
# ('Q9BYF1', 'ACE2')
# ('Q8TDN7', 'ACER1')
# ('Q5QJU3', 'ACER2')
# ('Q9NUN7', 'ACER3')
# ('P22303', 'ACHE')
# ('Q9UKV3', 'ACIN1')
# ('Q16570', 'ACKR1')
# ('O00590', 'ACKR2')
# ('P25106', 'ACKR3')
# ('Q9NPB9', 'ACKR4')
# ('P53396', 'ACLY')
# ('Q8TDX5', 'ACMSD')
# ('P21399', 'ACO1')
# ('Q99798', 'ACO2')
# ('A6NK06', 'ACOD1')
# ('Q86TX2', 'ACOT1')
# ('P49753', 'ACOT2')
# ('Q8N9L9', 'ACOT4')
# ('Q3I5F7', 'ACOT6')
# ('O00154', 'ACOT7')
# ('O14734', 'ACOT8')
# ('Q9Y305', 'ACOT9')
# ('Q8WXI4', 'ACOT11')
# ('Q8WYK0', 'ACOT12')
# ('Q9NPJ3', 'ACOT13')
# ('Q15067', 'ACOX1')
# ('Q99424', 'ACOX2')
# ('O15254', 'ACOX3')
# ('Q9NUZ1', 'ACOXL')
# ('P24666', 'ACP1')
# ('P11117', 'ACP2')
# ('P15309', 'ACP3')
# ('Q9BZG2', 'ACP4')
# ('P13686', 'ACP5')
# ('Q9NPH0', 'ACP6')
# ('Q6ZNF0', 'ACP7')
# ('P10323', 'ACR')
# ('Q8NEB7', 'ACRBP')
# ('P26436', 'ACRV1')
# ('Q96GR2', 'ACSBG1')
# ('Q5FVE4', 'ACSBG2')
# ('Q96CM8', 'ACSF2')
# ('Q4G176', 'ACSF3')
# ('P33121', 'ACSL1')
# ('O95573', 'ACSL3')
# ('O60488', 'ACSL4')
# ('Q9ULC5', 'ACSL5')
# ('Q9UKU0', 'ACSL6')
# ('Q08AH1', 'ACSM1')
# ('Q08AH3', 'ACSM2A')
# ('Q68CK6', 'ACSM2B')
# ('Q53FZ2', 'ACSM3')
# ('P0C7M7', 'ACSM4')
# ('Q6NUN0', 'ACSM5')
# ('Q6P461', 'ACSM6')
# ('Q9NUB1', 'ACSS1')
# ('Q9NR19', 'ACSS2')
# ('Q9H6R3', 'ACSS3')
# ('P68133', 'ACTA1')
# ('P62736', 'ACTA2')
# ('P60709', 'ACTB')
# ('Q562R1', 'ACTBL2')
# ('P68032', 'ACTC1')
# ('P63261', 'ACTG1')
# ('P63267', 'ACTG2')
# ('O96019', 'ACTL6A')
# ('O94805', 'ACTL6B')
# ('Q9Y615', 'ACTL7A')
# ('Q9Y614', 'ACTL7B')
# ('Q9H568', 'ACTL8')
# ('Q8TC94', 'ACTL9')
# ('Q5JWF8', 'ACTL10')
# ('P12814', 'ACTN1')
# ('P35609', 'ACTN2')
# ('Q08043', 'ACTN3')
# ('O43707', 'ACTN4')
# ('P61163', 'ACTR1A')
# ('P42025', 'ACTR1B')
# ('P61160', 'ACTR2')
# ('P61158', 'ACTR3')
# ('Q9P1U1', 'ACTR3B')
# ('Q9C0K3', 'ACTR3C')
# ('Q9H9F9', 'ACTR5')
# ('Q9GZN1', 'ACTR6')
# ('Q9H981', 'ACTR8')
# ('Q9NZ32', 'ACTR10')
# ('Q8TDG2', 'ACTRT1')
# ('Q8TDY3', 'ACTRT2')
# ('Q9BYD9', 'ACTRT3')
# ('Q04771', 'ACVR1')
# ('P36896', 'ACVR1B')
# ('Q8NER5', 'ACVR1C')
# ('P27037', 'ACVR2A')
# ('Q13705', 'ACVR2B')
# ('P37023', 'ACVRL1')
# ('Q03154', 'ACY1')
# ('Q96HD9', 'ACY3')
# ('P07311', 'ACYP1')
# ('P14621', 'ACYP2')
# ('P00813', 'ADA')
# ('Q9NZK5', 'ADA2')
# ('Q96M93', 'ADAD1')
# ('Q8NCV1', 'ADAD2')
# ('Q6DHV7', 'ADAL')
# ('Q99965', 'ADAM2')
# ('Q6NVV9', 'ADAM5')
# ('Q9H2U9', 'ADAM7')
# ('P78325', 'ADAM8')
# ('Q13443', 'ADAM9')
# ('O14672', 'ADAM10')
# ('O75078', 'ADAM11')
# ('O43184', 'ADAM12')
# ('Q13444', 'ADAM15')
# ('P78536', 'ADAM17')
# ('Q9Y3Q7', 'ADAM18')
# ('Q9H013', 'ADAM19')
# ('O43506', 'ADAM20')
# ('Q9UKJ8', 'ADAM21')
# ('Q9P0K1', 'ADAM22')
# ('O75077', 'ADAM23')
# ('Q9UKQ2', 'ADAM28')
# ('Q9UKF5', 'ADAM29')
# ('Q9UKF2', 'ADAM30')
# ('Q8TC27', 'ADAM32')
# ('Q9BZ11', 'ADAM33')
# ('O15204', 'ADAMDEC1')
# ('Q9UHI8', 'ADAMTS1')
# ('O95450', 'ADAMTS2')
# ('O15072', 'ADAMTS3')
# ('O75173', 'ADAMTS4')
# ('Q9UNA0', 'ADAMTS5')
# ('Q9UKP5', 'ADAMTS6')
# ('Q9UKP4', 'ADAMTS7')
# ('Q9UP79', 'ADAMTS8')
# ('Q9P2N4', 'ADAMTS9')
# ('Q9H324', 'ADAMTS10')
# ('P58397', 'ADAMTS12')
# ('Q76LX8', 'ADAMTS13')
# ('Q8WXS8', 'ADAMTS14')
# ('Q8TE58', 'ADAMTS15')
# ('Q8TE57', 'ADAMTS16')
# ('Q8TE56', 'ADAMTS17')
# ('Q8TE60', 'ADAMTS18')
# ('Q8TE59', 'ADAMTS19')
# ('P59510', 'ADAMTS20')
# ('Q8N6G6', 'ADAMTSL1')
# ('Q86TH1', 'ADAMTSL2')
# ('P82987', 'ADAMTSL3')
# ('Q6UY14', 'ADAMTSL4')
# ('Q5T5F5', 'ADAMTSL4-AS1')
# ('Q6ZMM2', 'ADAMTSL5')
# ('O75689', 'ADAP1')
# ('Q9NPF8', 'ADAP2')
# ('P55265', 'ADAR')
# ('P78563', 'ADARB1')
# ('Q9NS39', 'ADARB2')
# ('A8MUL3', 'ADARB2-AS1')
# ('Q9BUB4', 'ADAT1')
# ('Q7Z6V5', 'ADAT2')
# ('Q96EY9', 'ADAT3')
# ('Q86TW2', 'ADCK1')
# ('Q7Z695', 'ADCK2')
# ('Q3MIX3', 'ADCK5')
# ('Q08828', 'ADCY1')
# ('Q08462', 'ADCY2')
# ('O60266', 'ADCY3')
# ('Q8NFM4', 'ADCY4')
# ('O95622', 'ADCY5')
# ('O43306', 'ADCY6')
# ('P51828', 'ADCY7')
# ('P40145', 'ADCY8')
# ('O60503', 'ADCY9')
# ('Q96PN6', 'ADCY10')
# ('P18509', 'ADCYAP1')
# ('P41586', 'ADCYAP1R1')
# ('P35611', 'ADD1')
# ('P35612', 'ADD2')
# ('Q9UEY8', 'ADD3')
# ('Q8N7X0', 'ADGB')
# ('Q86SQ6', 'ADGRA1')
# ('Q96PE1', 'ADGRA2')
# ('Q8IWK6', 'ADGRA3')
# ('O14514', 'ADGRB1')
# ('O60241', 'ADGRB2')
# ('O60242', 'ADGRB3')
# ('Q6QNK2', 'ADGRD1')
# ('Q7Z7M1', 'ADGRD2')
# ('Q14246', 'ADGRE1')
# ('Q9UHX3', 'ADGRE2')
# ('Q9BY15', 'ADGRE3')
# ('Q86SQ3', 'ADGRE4P')
# ('P48960', 'ADGRE5')
# ('Q5T601', 'ADGRF1')
# ('Q8IZF7', 'ADGRF2')
# ('Q8IZF5', 'ADGRF3')
# ('Q8IZF3', 'ADGRF4')
# ('Q8IZF2', 'ADGRF5')
# ('Q9Y653', 'ADGRG1')
# ('Q8IZP9', 'ADGRG2')
# ('Q86Y34', 'ADGRG3')
# ('Q8IZF6', 'ADGRG4')
# ('Q8IZF4', 'ADGRG5')
# ('Q86SQ4', 'ADGRG6')
# ('Q96K78', 'ADGRG7')
# ('O94910', 'ADGRL1')
# ('O95490', 'ADGRL2')
# ('Q9HAR2', 'ADGRL3')
# ('Q9HBW9', 'ADGRL4')
# ('Q8WXG9', 'ADGRV1')
# ('P07327', 'ADH1A')
# ('P00325', 'ADH1B')
# ('P00326', 'ADH1C')
# ('P08319', 'ADH4')
# ('P11766', 'ADH5')
# ('P28332', 'ADH6')
# ('P40394', 'ADH7')
# ('Q8IWW8', 'ADHFE1')
# ('Q9BV57', 'ADI1')
# ('Q0VDE8', 'ADIG')
# ('Q15848', 'ADIPOQ')
# ('Q96A54', 'ADIPOR1')
# ('Q86V24', 'ADIPOR2')
# ('Q15847', 'ADIRF')
# ('P55263', 'ADK')
# ('P35318', 'ADM')
# ('Q7Z4H4', 'ADM2')
# ('C9JUS6', 'ADM5')
# ('Q9H2P0', 'ADNP')
# ('Q6IQ32', 'ADNP2')
# ('Q96SZ5', 'ADO')
# ('P30542', 'ADORA1')
# ('P29274', 'ADORA2A')
# ('P86434', 'ADORA2A-AS1')
# ('P29275', 'ADORA2B')
# ('P0DMS8', 'ADORA3')
# ('Q9BRR6', 'ADPGK')
# ('P54922', 'ADPRH')
# ('Q8NDY3', 'ADPRHL1')
# ('Q3LIE5', 'ADPRM')
# ('Q9NX46', 'ADPRS')
# ('P35348', 'ADRA1A')
# ('P35368', 'ADRA1B')
# ('P25100', 'ADRA1D')
# ('P08913', 'ADRA2A')
# ('P18089', 'ADRA2B')
# ('P18825', 'ADRA2C')
# ('P08588', 'ADRB1')
# ('P07550', 'ADRB2')
# ('P13945', 'ADRB3')
# ('Q16186', 'ADRM1')
# ('P30566', 'ADSL')
# ('Q8N142', 'ADSS1')
# ('P30520', 'ADSS2')
# ('Q96IZ2', 'ADTRP')
# ('Q8IUX7', 'AEBP1')
# ('Q6ZN18', 'AEBP2')
# ('Q8WTP8', 'AEN')
# ('Q8N556', 'AFAP1')
# ('Q8TED9', 'AFAP1L1')
# ('Q8N4X5', 'AFAP1L2')
# ('P55196', 'AFDN')
# ('Q9Y6Z5', 'AFDN-DT')
# ('P51825', 'AFF1')
# ('P51816', 'AFF2')
# ('P51826', 'AFF3')
# ('Q9UHB7', 'AFF4')
# ('Q8WV93', 'AFG1L')
# ('Q9Y4W6', 'AFG3L2')
# ('P43652', 'AFM')
# ('Q63HM1', 'AFMID')
# ('P02771', 'AFP')
# ('Q6ULP2', 'AFTPH')
# ('P20933', 'AGA')
# ('Q9UPQ3', 'AGAP1')
# ('Q99490', 'AGAP2')
# ('Q96P47', 'AGAP3')
# ('Q96P64', 'AGAP4')
# ('A6NIR3', 'AGAP5')
# ('Q5VW22', 'AGAP6')
# ('Q5VUJ5', 'AGAP7P')
# ('Q5VTM2', 'AGAP9')
# ('Q8TF27', 'AGAP11')
# ('Q96MI9', 'AGBL1')
# ('Q5U5Z8', 'AGBL2')
# ('Q8NEM8', 'AGBL3')
# ('Q5VU57', 'AGBL4')
# ('Q8NDL9', 'AGBL5')
# ('Q15109', 'AGER')
# ('P52594', 'AGFG1')
# ('O95081', 'AGFG2')
# ('Q8N302', 'AGGF1')
# ('Q53H12', 'AGK')
# ('P35573', 'AGL')
# ('Q9BSE5', 'AGMAT')
# ('Q6ZNB7', 'AGMO')
# ('Q9UL18', 'AGO1')
# ('Q9UKV8', 'AGO2')
# ('Q9H9G7', 'AGO3')
# ('Q9HCK5', 'AGO4')
# ('Q99943', 'AGPAT1')
# ('O15120', 'AGPAT2')
# ('Q9NRZ7', 'AGPAT3')
# ('Q9NRZ5', 'AGPAT4')
# ('Q9H0P7', 'AGPAT4-IT1')
# ('Q9NUQ2', 'AGPAT5')
# ('O00116', 'AGPS')
# ('O95994', 'AGR2')
# ('Q8TD06', 'AGR3')
# ('O00468', 'AGRN')
# ('O00253', 'AGRP')
# ('P01019', 'AGT')
# ('Q9UPW5', 'AGTPBP1')
# ('P30556', 'AGTR1')
# ('P50052', 'AGTR2')
# ('Q6RW13', 'AGTRAP')
# ('P21549', 'AGXT')
# ('Q9BYV1', 'AGXT2')
# ('Q8WYP5', 'AHCTF1')
# ('P23526', 'AHCY')
# ('O43865', 'AHCYL1')
# ('Q96HN2', 'AHCYL2')
# ('Q5TGY3', 'AHDC1')
# ('Q8N157', 'AHI1')
# ('Q09666', 'AHNAK')
# ('Q8IVF2', 'AHNAK2')
# ('P35869', 'AHR')
# ('A9YTQ3', 'AHRR')
# ('O95433', 'AHSA1')
# ('Q719I0', 'AHSA2P')
# ('P02765', 'AHSG')
# ('Q9NZD4', 'AHSP')
# ('Q9GZX7', 'AICDA')
# ('Q96BJ3', 'AIDA')
# ('P55008', 'AIF1')
# ('Q9BQI0', 'AIF1L')
# ('O95831', 'AIFM1')
# ('Q9BRQ8', 'AIFM2')
# ('Q96NN9', 'AIFM3')
# ('Q9NVV5', 'AIG1')
# ('O14862', 'AIM2')
# ('Q12904', 'AIMP1')
# ('Q13155', 'AIMP2')
# ('O00170', 'AIP')
# ('Q9NZN9', 'AIPL1')
# ('O43918', 'AIRE')
# ('Q9UKB5', 'AJAP1')
# ('C9J069', 'AJM1')
# ('Q96IF1', 'AJUBA')
# ('P00568', 'AK1')
# ('P54819', 'AK2')
# ('Q9UIJ7', 'AK3')
# ('P27144', 'AK4')
# ('Q9Y6K8', 'AK5')
# ('Q9Y3D8', 'AK6')
# ('Q96M32', 'AK7')
# ('Q96MA6', 'AK8')
# ('Q5TCS8', 'AK9')
# ('P0CW23', 'AKAIN1')
# ('Q92667', 'AKAP1')
# ('Q9Y2D5', 'AKAP2')
# ('O75969', 'AKAP3')
# ('Q5JQC9', 'AKAP4')
# ('P24588', 'AKAP5')
# ('Q13023', 'AKAP6')
# ('O43687', 'AKAP7')
# ('Q9P0M2', 'AKAP7')
# ('O43823', 'AKAP8')
# ('Q9ULX6', 'AKAP8L')
# ('Q99996', 'AKAP9')
# ('O43572', 'AKAP10')
# ('Q9UKA4', 'AKAP11')
# ('Q02952', 'AKAP12')
# ('Q12802', 'AKAP13')
# ('Q86UN6', 'AKAP14')
# ('Q02040', 'AKAP17A')
# ('Q9NQ31', 'AKIP1')
# ('Q9H9L7', 'AKIRIN1')
# ('Q53H80', 'AKIRIN2')
# ('Q7Z591', 'AKNA')
# ('Q5T1N1', 'AKNAD1')
# ('P14550', 'AKR1A1')
# ('P15121', 'AKR1B1')
# ('O60218', 'AKR1B10')
# ('C9JRZ8', 'AKR1B15')
# ('Q04828', 'AKR1C1')
# ('P52895', 'AKR1C2')
# ('P42330', 'AKR1C3')
# ('P17516', 'AKR1C4')
# ('Q5T2L2', 'AKR1C8P')
# ('P51857', 'AKR1D1')
# ('Q96JD6', 'AKR1E2')
# ('O43488', 'AKR7A2')
# ('O95154', 'AKR7A3')
# ('Q8NHP1', 'AKR7L')
# ('P31749', 'AKT1')
# ('Q96B36', 'AKT1S1')
# ('P31751', 'AKT2')
# ('Q9Y243', 'AKT3')
# ('Q9H8T0', 'AKTIP')
# ('P13716', 'ALAD')
# ('P13196', 'ALAS1')
# ('P22557', 'ALAS2')
# ('P02768', 'ALB')
# ('Q13740', 'ALCAM')
# ('P00352', 'ALDH1A1')
# ('O94788', 'ALDH1A2')
# ('P47895', 'ALDH1A3')
# ('P30837', 'ALDH1B1')
# ('O75891', 'ALDH1L1')
# ('Q3SY69', 'ALDH1L2')
# ('P05091', 'ALDH2')
# ('P30838', 'ALDH3A1')
# ('P51648', 'ALDH3A2')
# ('P43353', 'ALDH3B1')
# ('P48448', 'ALDH3B2')
# ('P30038', 'ALDH4A1')
# ('P51649', 'ALDH5A1')
# ('Q02252', 'ALDH6A1')
# ('P49419', 'ALDH7A1')
# ('Q9H2A2', 'ALDH8A1')
# ('P49189', 'ALDH9A1')
# ('Q8IZ83', 'ALDH16A1')
# ('P54886', 'ALDH18A1')
# ('P04075', 'ALDOA')
# ('P05062', 'ALDOB')
# ('P09972', 'ALDOC')
# ('Q9BT22', 'ALG1')
# ('Q6GMV1', 'ALG1L')
# ('C9J202', 'ALG1L2')
# ('Q9H553', 'ALG2')
# ('Q92685', 'ALG3')
# ('Q9Y673', 'ALG5')
# ('Q9Y672', 'ALG6')
# ('Q9BVK2', 'ALG8')
# ('Q9H6U8', 'ALG9')
# ('Q5BKT4', 'ALG10')
# ('Q5I7T1', 'ALG10B')
# ('Q2TAA5', 'ALG11')
# ('Q9BV10', 'ALG12')
# ('Q9NP73', 'ALG13')
# ('Q96F25', 'ALG14')
# ('Q9UM73', 'ALK')
# ('Q6UXT8', 'ALKAL1')
# ('Q6UX46', 'ALKAL2')
# ('Q13686', 'ALKBH1')
# ('Q6NS38', 'ALKBH2')
# ('Q96Q83', 'ALKBH3')
# ('Q9NXW9', 'ALKBH4')
# ('Q6P6C2', 'ALKBH5')
# ('Q3KRA9', 'ALKBH6')
# ('Q9BT30', 'ALKBH7')
# ('Q96BT7', 'ALKBH8')
# ('Q8N6M5', 'ALLC')
# ('Q8TCU4', 'ALMS1')
# ('P09917', 'ALOX5')
# ('P20292', 'ALOX5AP')
# ('P18054', 'ALOX12')
# ('O75342', 'ALOX12B')
# ('P16050', 'ALOX15')
# ('O15296', 'ALOX15B')
# ('Q9BYJ1', 'ALOXE3')
# ('P10696', 'ALPG')
# ('P09923', 'ALPI')
# ('Q96QP1', 'ALPK1')
# ('Q86TB3', 'ALPK2')
# ('Q96L96', 'ALPK3')
# ('P05186', 'ALPL')
# ('P05187', 'ALPP')
# ('Q96Q42', 'ALS2')
# ('Q60I27', 'ALS2CL')
# ('Q15699', 'ALX1')
# ('O95076', 'ALX3')
# ('Q9H161', 'ALX4')
# ('Q86V81', 'ALYREF')
# ('Q9UHK6', 'AMACR')
# ('Q9NP70', 'AMBN')
# ('P02760', 'AMBP')
# ('Q9C0C7', 'AMBRA1')
# ('P17707', 'AMD1')
# ('Q96NU7', 'AMDHD1')
# ('Q9Y303', 'AMDHD2')
# ('Q99217', 'AMELX')
# ('Q99218', 'AMELY')
# ('Q5JTC6', 'AMER1')
# ('Q8N7J2', 'AMER2')
# ('Q8N944', 'AMER3')
# ('Q9UKV5', 'AMFR')
# ('P03971', 'AMH')
# ('Q16671', 'AMHR2')
# ('Q86WK6', 'AMIGO1')
# ('Q86SJ2', 'AMIGO2')
# ('Q86WK7', 'AMIGO3')
# ('Q9Y4X0', 'AMMECR1')
# ('Q6DCA0', 'AMMECR1L')
# ('Q9BXJ7', 'AMN')
# ('Q8IY45', 'AMN1')
# ('Q4VCS5', 'AMOT')
# ('Q8IY63', 'AMOTL1')
# ('Q9Y2J4', 'AMOTL2')
# ('P23109', 'AMPD1')
# ('Q01433', 'AMPD2')
# ('Q01432', 'AMPD3')
# ('P49418', 'AMPH')
# ('P48728', 'AMT')
# ('Q6UX39', 'AMTN')
# ('P04745', 'AMY1C')
# ('P04746', 'AMY2A')
# ('P19961', 'AMY2B')
# ('Q400G9', 'AMZ1')
# ('Q86W34', 'AMZ2')
# ('Q9H1A4', 'ANAPC1')
# ('Q9UJX6', 'ANAPC2')
# ('Q9UJX5', 'ANAPC4')
# ('Q9UJX4', 'ANAPC5')
# ('Q9UJX3', 'ANAPC7')
# ('Q9UM13', 'ANAPC10')
# ('Q9NYG5', 'ANAPC11')
# ('Q9BS18', 'ANAPC13')
# ('P60006', 'ANAPC15')
# ('Q96DE5', 'ANAPC16')
# ('P03950', 'ANG')
# ('Q9UNK9', 'ANGEL1')
# ('Q5VTE6', 'ANGEL2')
# ('Q15389', 'ANGPT1')
# ('O15123', 'ANGPT2')
# ('Q9Y264', 'ANGPT4')
# ('O95841', 'ANGPTL1')
# ('Q9UKU9', 'ANGPTL2')
# ('Q9Y5C1', 'ANGPTL3')
# ('Q9BY76', 'ANGPTL4')
# ('Q86XS5', 'ANGPTL5')
# ('Q8NI99', 'ANGPTL6')
# ('O43827', 'ANGPTL7')
# ('Q6UXH0', 'ANGPTL8')
# ('E9PGG2', 'ANHX')
# ('P16157', 'ANK1')
# ('Q01484', 'ANK2')
# ('Q12955', 'ANK3')
# ('Q7Z5J8', 'ANKAR')
# ('Q495B1', 'ANKDD1A')
# ('A6NHY2', 'ANKDD1B')
# ('Q9NU02', 'ANKEF1')
# ('Q8N957', 'ANKFN1')
# ('Q9P2R3', 'ANKFY1')
# ('Q9HCJ1', 'ANKH')
# ('Q8IWZ3', 'ANKHD1')
# ('Q9P2G1', 'ANKIB1')
# ('Q8NFD2', 'ANKK1')
# ('Q8NAG6', 'ANKLE1')
# ('Q86XL3', 'ANKLE2')
# ('Q9P2S6', 'ANKMY1')
# ('Q8IV38', 'ANKMY2')
# ('Q9H9E1', 'ANKRA2')
# ('Q15327', 'ANKRD1')
# ('Q9GZV1', 'ANKRD2')
# ('Q9Y2G4', 'ANKRD6')
# ('Q92527', 'ANKRD7')
# ('Q96BM1', 'ANKRD9')
# ('Q9NXR5', 'ANKRD10')
# ('Q6UB99', 'ANKRD11')
# ('Q6UB98', 'ANKRD12')
# ('Q8IZ07', 'ANKRD13A')
# ('Q86YJ7', 'ANKRD13B')
# ('Q8N6S4', 'ANKRD13C')
# ('Q6ZTN6', 'ANKRD13D')
# ('Q6P6B7', 'ANKRD16')
# ('O75179', 'ANKRD17')
# ('Q8IVF6', 'ANKRD18A')
# ('A2A2Z9', 'ANKRD18B')
# ('Q9H560', 'ANKRD19P')
# ('Q5TYW2', 'ANKRD20A1')
# ('Q5SQ80', 'ANKRD20A2P')
# ('Q5VUR7', 'ANKRD20A3P')
# ('Q4UJ75', 'ANKRD20A4P')
# ('A0PJZ0', 'ANKRD20A5P')
# ('Q5CZ79', 'ANKRD20A8P')
# ('Q8NF67', 'ANKRD20A12P')
# ('Q5VYY1', 'ANKRD22')
# ('Q86SG2', 'ANKRD23')
# ('Q8TF21', 'ANKRD24')
# ('Q9UPS8', 'ANKRD26')
# ('Q6NSI1', 'ANKRD26P1')
# ('Q96NW4', 'ANKRD27')
# ('O15084', 'ANKRD28')
# ('Q8N6D5', 'ANKRD29')
# ('Q9BXX3', 'ANKRD30A')
# ('Q9BXX2', 'ANKRD30B')
# ('A7E2S9', 'ANKRD30BL')
# ('Q8N7Z5', 'ANKRD31')
# ('Q7Z3H0', 'ANKRD33')
# ('A6NCL7', 'ANKRD33B')
# ('Q69YU3', 'ANKRD34A')
# ('A5PLL1', 'ANKRD34B')
# ('P0C6C1', 'ANKRD34C')
# ('Q8N283', 'ANKRD35')
# ('A6QL64', 'ANKRD36')
# ('Q8N2N9', 'ANKRD36B')
# ('Q96IX9', 'ANKRD36BP1')
# ('Q5JPF3', 'ANKRD36C')
# ('Q7Z713', 'ANKRD37')
# ('Q53RE8', 'ANKRD39')
# ('Q6AI12', 'ANKRD40')
# ('Q53H64', 'ANKRD40CL')
# ('Q8N9B4', 'ANKRD42')
# ('Q8N8A2', 'ANKRD44')
# ('Q5TZF3', 'ANKRD45')
# ('Q86W74', 'ANKRD46')
# ('Q8WVL7', 'ANKRD49')
# ('Q9ULJ7', 'ANKRD50')
# ('Q8NB46', 'ANKRD52')
# ('Q8N9V6', 'ANKRD53')
# ('Q6NXT1', 'ANKRD54')
# ('Q3KP44', 'ANKRD55')
# ('Q9BZ19', 'ANKRD60')
# ('A6NGH8', 'ANKRD61')
# ('A6NC57', 'ANKRD62')
# ('C9JTQ0', 'ANKRD63')
# ('E5RJM6', 'ANKRD65')
# ('B4E2M5', 'ANKRD66')
# ('Q92625', 'ANKS1A')
# ('Q7Z6G8', 'ANKS1B')
# ('Q6ZW76', 'ANKS3')
# ('Q8N8V4', 'ANKS4B')
# ('Q68DC2', 'ANKS6')
# ('A6NFN9', 'ANKUB1')
# ('Q9H8Y5', 'ANKZF1')
# ('Q9NQW6', 'ANLN')
# ('Q5XXA6', 'ANO1')
# ('Q9NQ90', 'ANO2')
# ('Q9BYT9', 'ANO3')
# ('Q32M45', 'ANO4')
# ('Q75V66', 'ANO5')
# ('Q4KMQ2', 'ANO6')
# ('Q6IWH7', 'ANO7')
# ('Q9HCE9', 'ANO8')
# ('A1A5B4', 'ANO9')
# ('Q9NW15', 'ANO10')
# ('P23352', 'ANOS1')
# ('P39687', 'ANP32A')
# ('Q92688', 'ANP32B')
# ('O43423', 'ANP32C')
# ('O95626', 'ANP32D')
# ('Q9BTT0', 'ANP32E')
# ('P15144', 'ANPEP')
# ('Q9BQD7', 'ANTKMT')
# ('Q9H6X2', 'ANTXR1')
# ('P58335', 'ANTXR2')
# ('A6NF34', 'ANTXRL')
# ('P04083', 'ANXA1')
# ('P07355', 'ANXA2')
# ('A6NMY6', 'ANXA2P2')
# ('Q3ZCQ2', 'ANXA2R')
# ('P12429', 'ANXA3')
# ('P09525', 'ANXA4')
# ('P08758', 'ANXA5')
# ('P08133', 'ANXA6')
# ('P20073', 'ANXA7')
# ('P13928', 'ANXA8')
# ('Q5VT79', 'ANXA8L1')
# ('O76027', 'ANXA9')
# ('Q9UJ72', 'ANXA10')
# ('P50995', 'ANXA11')
# ('P27216', 'ANXA13')
# ('P28039', 'AOAH')
# ('P19801', 'AOC1')
# ('O75106', 'AOC2')
# ('Q16853', 'AOC3')
# ('Q8N6M6', 'AOPEP')
# ('Q06278', 'AOX1')
# ('Q63HQ0', 'AP1AR')
# ('Q10567', 'AP1B1')
# ('O43747', 'AP1G1')
# ('O75843', 'AP1G2')
# ('Q9BXS5', 'AP1M1')
# ('Q9Y6Q5', 'AP1M2')
# ('P61966', 'AP1S1')
# ('P56377', 'AP1S2')
# ('Q96PC3', 'AP1S3')
# ('O95782', 'AP2A1')
# ('O94973', 'AP2A2')
# ('P63010', 'AP2B1')
# ('Q96CW1', 'AP2M1')
# ('P53680', 'AP2S1')
# ('O00203', 'AP3B1')
# ('Q13367', 'AP3B2')
# ('O14617', 'AP3D1')
# ('Q9Y2T2', 'AP3M1')
# ('P53677', 'AP3M2')
# ('Q92572', 'AP3S1')
# ('P59780', 'AP3S2')
# ('Q9Y6B7', 'AP4B1')
# ('Q9UPM8', 'AP4E1')
# ('O00189', 'AP4M1')
# ('Q9Y587', 'AP4S1')
# ('Q2VPB7', 'AP5B1')
# ('Q9H0R1', 'AP5M1')
# ('Q9NUS5', 'AP5S1')
# ('O43299', 'AP5Z1')
# ('O14727', 'APAF1')
# ('Q02410', 'APBA1')
# ('Q99767', 'APBA2')
# ('O96018', 'APBA3')
# ('O00213', 'APBB1')
# ('Q7Z5R6', 'APBB1IP')
# ('Q92870', 'APBB2')
# ('O95704', 'APBB3')
# ('P25054', 'APC')
# ('O95996', 'APC2')
# ('Q8J025', 'APCDD1')
# ('Q8NCL9', 'APCDD1L')
# ('P02743', 'APCS')
# ('P13798', 'APEH')
# ('P0DMC3', 'APELA')
# ('P27695', 'APEX1')
# ('Q9UBZ4', 'APEX2')
# ('Q96BI3', 'APH1A')
# ('Q8WW43', 'APH1B')
# ('Q9BZZ5', 'API5')
# ('Q96GX9', 'APIP')
# ('Q8IW19', 'APLF')
# ('Q9ULZ1', 'APLN')
# ('P35414', 'APLNR')
# ('P51693', 'APLP1')
# ('Q06481', 'APLP2')
# ('Q9HDC9', 'APMAP')
# ('P02647', 'APOA1')
# ('P02652', 'APOA2')
# ('P06727', 'APOA4')
# ('Q6Q788', 'APOA5')
# ('P04114', 'APOB')
# ('P41238', 'APOBEC1')
# ('Q9Y235', 'APOBEC2')
# ('P31941', 'APOBEC3A')
# ('Q9UH17', 'APOBEC3B')
# ('Q9NRW3', 'APOBEC3C')
# ('Q96AK3', 'APOBEC3D')
# ('Q8IUX4', 'APOBEC3F')
# ('Q9HC16', 'APOBEC3G')
# ('Q6NTF7', 'APOBEC3H')
# ('Q8WW27', 'APOBEC4')
# ('Q0VD83', 'APOBR')
# ('P02654', 'APOC1')
# ('P02655', 'APOC2')
# ('P02656', 'APOC3')
# ('P55056', 'APOC4')
# ('P05090', 'APOD')
# ('P02649', 'APOE')
# ('Q13790', 'APOF')
# ('P02749', 'APOH')
# ('O14791', 'APOL1')
# ('Q9BQE5', 'APOL2')
# ('O95236', 'APOL3')
# ('Q9BPW4', 'APOL4')
# ('Q9BWW9', 'APOL5')
# ('Q9BWW8', 'APOL6')
# ('Q96LR9', 'APOLD1')
# ('O95445', 'APOM')
# ('Q9BUR5', 'APOO')
# ('Q6UXV4', 'APOOL')
# ('P05067', 'APP')
# ('Q92624', 'APPBP2')
# ('Q9UKG1', 'APPL1')
# ('Q8NEU8', 'APPL2')
# ('P07741', 'APRT')
# ('Q7Z2E3', 'APTX')
# ('P29972', 'AQP1')
# ('P41181', 'AQP2')
# ('Q92482', 'AQP3')
# ('P55087', 'AQP4')
# ('P55064', 'AQP5')
# ('Q13520', 'AQP6')
# ('O14520', 'AQP7')
# ('A6NL99', 'AQP7P3')
# ('O94778', 'AQP8')
# ('O43315', 'AQP9')
# ('Q96PS8', 'AQP10')
# ('Q8NBQ7', 'AQP11')
# ('Q8IXF9', 'AQP12A')
# ('A6NM10', 'AQP12B')
# ('O60306', 'AQR')
# ('P10275', 'AR')
# ('P10398', 'ARAF')
# ('Q96P48', 'ARAP1')
# ('Q8WZ64', 'ARAP2')
# ('Q8WWN8', 'ARAP3')
# ('Q7LC44', 'ARC')
# ('P48444', 'ARCN1')
# ('P15514', 'AREG')
# ('O15033', 'AREL1')
# ('P84077', 'ARF1')
# ('P61204', 'ARF3')
# ('P18085', 'ARF4')
# ('P84085', 'ARF5')
# ('P62330', 'ARF6')
# ('Q8N6T3', 'ARFGAP1')
# ('Q8N6H7', 'ARFGAP2')
# ('Q9NP61', 'ARFGAP3')
# ('Q9Y6D6', 'ARFGEF1')
# ('Q9Y6D5', 'ARFGEF2')
# ('Q5TH69', 'ARFGEF3')
# ('P53367', 'ARFIP1')
# ('P53365', 'ARFIP2')
# ('Q13795', 'ARFRP1')
# ('P05089', 'ARG1')
# ('P78540', 'ARG2')
# ('A6NJG6', 'ARGFX')
# ('Q9NWB6', 'ARGLU1')
# ('Q07960', 'ARHGAP1')
# ('P98171', 'ARHGAP4')
# ('Q13017', 'ARHGAP5')
# ('Q96IT6', 'ARHGAP5-AS1')
# ('O43182', 'ARHGAP6')
# ('P85298', 'ARHGAP8')
# ('Q9BRR9', 'ARHGAP9')
# ('A1A4S6', 'ARHGAP10')
# ('Q6P4F7', 'ARHGAP11A')
# ('Q3KRB8', 'ARHGAP11B')
# ('Q8IWW6', 'ARHGAP12')
# ('Q53QZ3', 'ARHGAP15')
# ('Q68EM7', 'ARHGAP17')
# ('Q8N392', 'ARHGAP18')
# ('Q14CB8', 'ARHGAP19')
# ('Q9P2F6', 'ARHGAP20')
# ('Q5T5U3', 'ARHGAP21')
# ('Q7Z5H3', 'ARHGAP22')
# ('Q9P227', 'ARHGAP23')
# ('Q8N264', 'ARHGAP24')
# ('P42331', 'ARHGAP25')
# ('Q9UNA1', 'ARHGAP26')
# ('Q6ZUM4', 'ARHGAP27')
# ('Q9P2N2', 'ARHGAP28')
# ('Q52LW3', 'ARHGAP29')
# ('Q7Z6I6', 'ARHGAP30')
# ('Q2M1Z3', 'ARHGAP31')
# ('A7KAX9', 'ARHGAP32')
# ('O14559', 'ARHGAP33')
# ('Q9NRY4', 'ARHGAP35')
# ('Q6ZRI8', 'ARHGAP36')
# ('Q9C0H5', 'ARHGAP39')
# ('Q5TG30', 'ARHGAP40')
# ('A6NI28', 'ARHGAP42')
# ('Q17R89', 'ARHGAP44')
# ('Q92619', 'ARHGAP45')
# ('P52565', 'ARHGDIA')
# ('P52566', 'ARHGDIB')
# ('Q99819', 'ARHGDIG')
# ('Q92888', 'ARHGEF1')
# ('Q92974', 'ARHGEF2')
# ('Q9NR81', 'ARHGEF3')
# ('Q9NR80', 'ARHGEF4')
# ('Q12774', 'ARHGEF5')
# ('Q15052', 'ARHGEF6')
# ('Q14155', 'ARHGEF7')
# ('O43307', 'ARHGEF9')
# ('O15013', 'ARHGEF10')
# ('Q9HCE6', 'ARHGEF10L')
# ('O15085', 'ARHGEF11')
# ('Q9NZN5', 'ARHGEF12')
# ('O94989', 'ARHGEF15')
# ('Q5VV41', 'ARHGEF16')
# ('Q96PE2', 'ARHGEF17')
# ('Q6ZSZ5', 'ARHGEF18')
# ('Q8IW93', 'ARHGEF19')
# ('Q86VW2', 'ARHGEF25')
# ('Q96DR7', 'ARHGEF26')
# ('Q8N1W1', 'ARHGEF28')
# ('A8MVX0', 'ARHGEF33')
# ('A5YM69', 'ARHGEF35')
# ('A1IGU5', 'ARHGEF37')
# ('Q9NXL2', 'ARHGEF38')
# ('Q8N4T4', 'ARHGEF39')
# ('Q8TER5', 'ARHGEF40')
# ('O14497', 'ARID1A')
# ('Q8NFD5', 'ARID1B')
# ('Q68CP9', 'ARID2')
# ('Q99856', 'ARID3A')
# ('Q8IVW6', 'ARID3B')
# ('A6NKF2', 'ARID3C')
# ('P29374', 'ARID4A')
# ('Q4LE39', 'ARID4B')
# ('Q03989', 'ARID5A')
# ('Q14865', 'ARID5B')
# ('Q9Y4X5', 'ARIH1')
# ('O95376', 'ARIH2')
# ('Q8N7S6', 'ARIH2OS')
# ('P40616', 'ARL1')
# ('P36404', 'ARL2')
# ('Q9Y2Y0', 'ARL2BP')
# ('P36405', 'ARL3')
# ('P40617', 'ARL4A')
# ('P56559', 'ARL4C')
# ('P49703', 'ARL4D')
# ('Q9Y689', 'ARL5A')
# ('Q96KC2', 'ARL5B')
# ('A6NH57', 'ARL5C')
# ('Q9H0F7', 'ARL6')
# ('Q15041', 'ARL6IP1')
# ('Q66PJ3', 'ARL6IP4')
# ('O75915', 'ARL6IP5')
# ('Q8N6S5', 'ARL6IP6')
# ('Q96BM9', 'ARL8A')
# ('Q9NVJ2', 'ARL8B')
# ('Q6T311', 'ARL9')
# ('Q8N8L6', 'ARL10')
# ('Q969Q4', 'ARL11')
# ('Q5H913', 'ARL13A')
# ('Q3SXY8', 'ARL13B')
# ('Q8N4G2', 'ARL14')
# ('Q8N8R7', 'ARL14EP')
# ('P0DKL9', 'ARL14EPL')
# ('Q9NXU5', 'ARL15')
# ('Q0P5N6', 'ARL16')
# ('Q8IVW1', 'ARL17B')
# ('Q9NVT9', 'ARMC1')
# ('Q8NEN0', 'ARMC2')
# ('Q5W041', 'ARMC3')
# ('Q5T2S8', 'ARMC4')
# ('Q96C12', 'ARMC5')
# ('Q6NXE6', 'ARMC6')
# ('Q9H6L4', 'ARMC7')
# ('Q8IUR7', 'ARMC8')
# ('Q7Z3E5', 'ARMC9')
# ('Q8N2F6', 'ARMC10')
# ('Q5T9G4', 'ARMC12')
# ('Q9P291', 'ARMCX1')
# ('Q7L311', 'ARMCX2')
# ('Q9UH62', 'ARMCX3')
# ('Q5H9R4', 'ARMCX4')
# ('Q6P1M9', 'ARMCX5')
# ('Q7L4S7', 'ARMCX6')
# ('Q6PIY5', 'ARMH1')
# ('H3BNL8', 'ARMH2')
# ('Q5T2E6', 'ARMH3')
# ('Q86TY3', 'ARMH4')
# ('P0C7Q2', 'ARMS2')
# ('Q9H993', 'ARMT1')
# ('P27540', 'ARNT')
# ('Q9HBZ2', 'ARNT2')
# ('O00327', 'ARNTL')
# ('Q8WYA1', 'ARNTL2')
# ('Q92747', 'ARPC1A')
# ('O15143', 'ARPC1B')
# ('O15144', 'ARPC2')
# ('O15145', 'ARPC3')
# ('P59998', 'ARPC4')
# ('O15511', 'ARPC5')
# ('Q9BPX5', 'ARPC5L')
# ('Q7Z6K5', 'ARPIN')
# ('P56211', 'ARPP19')
# ('Q9UBL0', 'ARPP21')
# ('P36575', 'ARR3')
# ('P49407', 'ARRB1')
# ('P32121', 'ARRB2')
# ('Q8N5I2', 'ARRDC1')
# ('Q9H2J1', 'ARRDC1-AS1')
# ('Q8TBH0', 'ARRDC2')
# ('Q96B67', 'ARRDC3')
# ('Q8NCT1', 'ARRDC4')
# ('A6NEK1', 'ARRDC5')
# ('P15289', 'ARSA')
# ('P15848', 'ARSB')
# ('P51689', 'ARSD')
# ('P54793', 'ARSF')
# ('Q96EG1', 'ARSG')
# ('Q5FYA8', 'ARSH')
# ('Q5FYB1', 'ARSI')
# ('Q5FYB0', 'ARSJ')
# ('Q6UWY0', 'ARSK')
# ('P51690', 'ARSL')
# ('P52961', 'ART1')
# ('Q13508', 'ART3')
# ('Q93070', 'ART4')
# ('Q96L15', 'ART5')
# ('Q5T4W7', 'ARTN')
# ('Q9H2C2', 'ARV1')
# ('O00192', 'ARVCF')
# ('Q96QS3', 'ARX')
# ('Q9HBK9', 'AS3MT')
# ('Q13510', 'ASAH1')
# ('Q9NR71', 'ASAH2')
# ('P0C7U1', 'ASAH2B')
# ('Q9ULH1', 'ASAP1')
# ('O43150', 'ASAP2')
# ('Q8TDY4', 'ASAP3')
# ('Q9Y576', 'ASB1')
# ('Q96Q27', 'ASB2')
# ('Q9Y575', 'ASB3')
# ('Q9Y574', 'ASB4')
# ('Q8WWX0', 'ASB5')
# ('Q9NWX5', 'ASB6')
# ('Q9H672', 'ASB7')
# ('Q9H765', 'ASB8')
# ('Q96DX5', 'ASB9')
# ('Q8WXI3', 'ASB10')
# ('Q8WXH4', 'ASB11')
# ('Q8WXK4', 'ASB12')
# ('Q8WXK3', 'ASB13')
# ('A6NK59', 'ASB14')
# ('Q8WXK1', 'ASB15')
# ('Q96NS5', 'ASB16')
# ('Q495Z4', 'ASB16-AS1')
# ('Q8WXJ9', 'ASB17')
# ('Q6ZVZ8', 'ASB18')
# ('Q8N9N2', 'ASCC1')
# ('Q9H1I8', 'ASCC2')
# ('Q8N3C0', 'ASCC3')
# ('P50553', 'ASCL1')
# ('Q99929', 'ASCL2')
# ('Q9NQ33', 'ASCL3')
# ('Q6XD76', 'ASCL4')
# ('Q7RTU5', 'ASCL5')
# ('L0R819', 'ASDURF')
# ('Q9Y294', 'ASF1A')
# ('Q9NVP2', 'ASF1B')
# ('P07306', 'ASGR1')
# ('P07307', 'ASGR2')
# ('Q9NR48', 'ASH1L')
# ('Q9UBL3', 'ASH2L')
# ('P78348', 'ASIC1')
# ('Q16515', 'ASIC2')
# ('Q9UHC3', 'ASIC3')
# ('Q96FT7', 'ASIC4')
# ('Q9NY37', 'ASIC5')
# ('P42127', 'ASIP')
# ('P04424', 'ASL')
# ('P46597', 'ASMT')
# ('O95671', 'ASMTL')
# ('P08243', 'ASNS')
# ('Q9NWL6', 'ASNSD1')
# ('P45381', 'ASPA')
# ('A6ND91', 'ASPDH')
# ('Q86U10', 'ASPG')
# ('Q12797', 'ASPH')
# ('Q5U4P2', 'ASPHD1')
# ('Q6ICH7', 'ASPHD2')
# ('Q8IZT6', 'ASPM')
# ('Q9BXN1', 'ASPN')
# ('Q53RT3', 'ASPRV1')
# ('Q9BZE9', 'ASPSCR1')
# ('Q7L266', 'ASRGL1')
# ('P00966', 'ASS1')
# ('Q2TB18', 'ASTE1')
# ('Q6HA08', 'ASTL')
# ('O14525', 'ASTN1')
# ('O75129', 'ASTN2')
# ('Q8IXJ9', 'ASXL1')
# ('Q76L83', 'ASXL2')
# ('Q9C0F0', 'ASXL3')
# ('Q8WWH4', 'ASZ1')
# ('Q8NBU5', 'ATAD1')
# ('Q6PL18', 'ATAD2')
# ('Q9ULI0', 'ATAD2B')
# ('Q9NVI7', 'ATAD3A')
# ('Q5T9A4', 'ATAD3B')
# ('Q5T2N8', 'ATAD3C')
# ('Q96QE3', 'ATAD5')
# ('Q5SQI0', 'ATAT1')
# ('Q86WG3', 'ATCAY')
# ('O95260', 'ATE1')
# ('P18846', 'ATF1')
# ('P15336', 'ATF2')
# ('P18847', 'ATF3')
# ('P18848', 'ATF4')
# ('Q9Y2D1', 'ATF5')
# ('P18850', 'ATF6')
# ('Q99941', 'ATF6B')
# ('P17544', 'ATF7')
# ('Q6VMQ6', 'ATF7IP')
# ('Q5U623', 'ATF7IP2')
# ('Q2TAZ0', 'ATG2A')
# ('Q96BY7', 'ATG2B')
# ('Q9NT62', 'ATG3')
# ('Q8WYN0', 'ATG4A')
# ('Q9Y4P1', 'ATG4B')
# ('Q96DT6', 'ATG4C')
# ('Q86TL0', 'ATG4D')
# ('Q9H1Y0', 'ATG5')
# ('O95352', 'ATG7')
# ('Q7Z3C6', 'ATG9A')
# ('Q674R7', 'ATG9B')
# ('Q9H0Y0', 'ATG10')
# ('O94817', 'ATG12')
# ('O75143', 'ATG13')
# ('Q6ZNE5', 'ATG14')
# ('Q676U5', 'ATG16L1')
# ('Q8NAA4', 'ATG16L2')
# ('Q9BSB4', 'ATG101')
# ('P31939', 'ATIC')
# ('Q8WXF7', 'ATL1')
# ('Q8NHH9', 'ATL2')
# ('Q6DD88', 'ATL3')
# ('Q13315', 'ATM')
# ('O43313', 'ATMIN')
# ('P54259', 'ATN1')
# ('Q92858', 'ATOH1')
# ('Q8N100', 'ATOH7')
# ('Q96SQ7', 'ATOH8')
# ('O00244', 'ATOX1')
# ('P05023', 'ATP1A1')
# ('Q5TC04', 'ATP1A1-AS1')
# ('P50993', 'ATP1A2')
# ('P13637', 'ATP1A3')
# ('Q13733', 'ATP1A4')
# ('P05026', 'ATP1B1')
# ('P14415', 'ATP1B2')
# ('P54709', 'ATP1B3')
# ('Q9UN42', 'ATP1B4')
# ('O14983', 'ATP2A1')
# ('P16615', 'ATP2A2')
# ('Q93084', 'ATP2A3')
# ('P20020', 'ATP2B1')
# ('Q01814', 'ATP2B2')
# ('Q16720', 'ATP2B3')
# ('P23634', 'ATP2B4')
# ('P98194', 'ATP2C1')
# ('O75185', 'ATP2C2')
# ('P20648', 'ATP4A')
# ('P51164', 'ATP4B')
# ('P25705', 'ATP5F1A')
# ('P06576', 'ATP5F1B')
# ('P36542', 'ATP5F1C')
# ('P30049', 'ATP5F1D')
# ('P56381', 'ATP5F1E')
# ('Q5VTU8', 'ATP5F1EP2')
# ('Q9UII2', 'ATP5IF1')
# ('P05496', 'ATP5MC1')
# ('Q06055', 'ATP5MC2')
# ('P48201', 'ATP5MC3')
# ('Q96IX5', 'ATP5MD')
# ('P56385', 'ATP5ME')
# ('P56134', 'ATP5MF')
# ('O75964', 'ATP5MG')
# ('Q7Z4Y8', 'ATP5MGL')
# ('P56378', 'ATP5MPL')
# ('P24539', 'ATP5PB')
# ('O75947', 'ATP5PD')
# ('P18859', 'ATP5PF')
# ('P48047', 'ATP5PO')
# ('Q15904', 'ATP6AP1')
# ('Q52LC2', 'ATP6AP1L')
# ('O75787', 'ATP6AP2')
# ('P38606', 'ATP6V1A')
# ('P15313', 'ATP6V1B1')
# ('P21281', 'ATP6V1B2')
# ('P21283', 'ATP6V1C1')
# ('Q8NEY4', 'ATP6V1C2')
# ('Q9Y5K8', 'ATP6V1D')
# ('P36543', 'ATP6V1E1')
# ('Q96A05', 'ATP6V1E2')
# ('Q16864', 'ATP6V1F')
# ('A0A1B0GUX0', 'ATP6V1FNB')
# ('O75348', 'ATP6V1G1')
# ('O95670', 'ATP6V1G2')
# ('Q96LB4', 'ATP6V1G3')
# ('Q9UI12', 'ATP6V1H')
# ('Q93050', 'ATP6V0A1')
# ('Q9Y487', 'ATP6V0A2')
# ('Q9HBG4', 'ATP6V0A4')
# ('Q99437', 'ATP6V0B')
# ('P27449', 'ATP6V0C')
# ('P61421', 'ATP6V0D1')
# ('Q8N8Y2', 'ATP6V0D2')
# ('O15342', 'ATP6V0E1')
# ('Q8NHE4', 'ATP6V0E2')
# ('Q04656', 'ATP7A')
# ('P35670', 'ATP7B')
# ('Q9Y2Q0', 'ATP8A1')
# ('Q9NTI2', 'ATP8A2')
# ('O43520', 'ATP8B1')
# ('P98198', 'ATP8B2')
# ('O60423', 'ATP8B3')
# ('Q8TF62', 'ATP8B4')
# ('O75110', 'ATP9A')
# ('O43861', 'ATP9B')
# ('O60312', 'ATP10A')
# ('O94823', 'ATP10B')
# ('Q9P241', 'ATP10D')
# ('P98196', 'ATP11A')
# ('Q6ZP68', 'ATP11AUN')
# ('Q9Y2G3', 'ATP11B')
# ('Q8NB49', 'ATP11C')
# ('P54707', 'ATP12A')
# ('Q9HD20', 'ATP13A1')
# ('Q9NQ11', 'ATP13A2')
# ('Q9H7F0', 'ATP13A3')
# ('Q4VNC1', 'ATP13A4')
# ('Q4VNC0', 'ATP13A5')
# ('Q9Y6H3', 'ATP23')
# ('Q5TC12', 'ATPAF1')
# ('Q8N5M1', 'ATPAF2')
# ('Q6P4H8', 'ATPSCKMT')
# ('Q13535', 'ATR')
# ('Q6UW56', 'ATRAID')
# ('Q8WXE1', 'ATRIP')
# ('O75882', 'ATRN')
# ('Q5VV63', 'ATRNL1')
# ('P46100', 'ATRX')
# ('P54253', 'ATXN1')
# ('P0C7T5', 'ATXN1L')
# ('Q99700', 'ATXN2')
# ('Q8WWM7', 'ATXN2L')
# ('P54252', 'ATXN3')
# ('Q9H3M9', 'ATXN3L')
# ('O15265', 'ATXN7')
# ('Q9ULK2', 'ATXN7L1')
# ('Q5T6C5', 'ATXN7L2')
# ('Q14CW9', 'ATXN7L3')
# ('Q96GX2', 'ATXN7L3B')
# ('Q156A1', 'ATXN8')
# ('P0DMR3', 'ATXN8OS')
# ('Q9UBB4', 'ATXN10')
# ('Q13825', 'AUH')
# ('Q9H7T9', 'AUNIP')
# ('Q9Y679', 'AUP1')
# ('O14965', 'AURKA')
# ('Q9NWT8', 'AURKAIP1')
# ('Q96GD4', 'AURKB')
# ('Q9UQB9', 'AURKC')
# ('Q8WXX7', 'AUTS2')
# ('Q9NQS1', 'AVEN')
# ('O75366', 'AVIL')
# ('Q8NBF6', 'AVL9')
# ('P01185', 'AVP')
# ('Q5T686', 'AVPI1')
# ('P37288', 'AVPR1A')
# ('P47901', 'AVPR1B')
# ('P30518', 'AVPR2')
# ('Q58HT5', 'AWAT1')
# ('Q6E213', 'AWAT2')
# ('Q5T1B0', 'AXDND1')
# ('O15169', 'AXIN1')
# ('Q9Y2T1', 'AXIN2')
# ('P30530', 'AXL')
# ('P25311', 'AZGP1')
# ('Q9H6S1', 'AZI2')
# ('O14977', 'AZIN1')
# ('Q96A70', 'AZIN2')
# ('P20160', 'AZU1')
# ('P61769', 'B2M')
# ('O75752', 'B3GALNT1')
# ('Q8NCR0', 'B3GALNT2')
# ('Q9Y5Z6', 'B3GALT1')
# ('O43825', 'B3GALT2')
# ('O96024', 'B3GALT4')
# ('Q9Y2C3', 'B3GALT5')
# ('P59052', 'B3GALT5-AS1')
# ('Q96L58', 'B3GALT6')
# ('Q9P2W7', 'B3GAT1')
# ('Q9NPZ5', 'B3GAT2')
# ('O94766', 'B3GAT3')
# ('Q6Y288', 'B3GLCT')
# ('Q9NY97', 'B3GNT2')
# ('Q9Y2A9', 'B3GNT3')
# ('Q9C0J1', 'B3GNT4')
# ('Q9BYG0', 'B3GNT5')
# ('Q6ZMB0', 'B3GNT6')
# ('Q8NFL0', 'B3GNT7')
# ('Q7Z7M8', 'B3GNT8')
# ('Q6UX72', 'B3GNT9')
# ('Q67FW5', 'B3GNTL1')
# ('Q00973', 'B4GALNT1')
# ('Q8NHY0', 'B4GALNT2')
# ('Q6L9W6', 'B4GALNT3')
# ('Q76KP1', 'B4GALNT4')
# ('P15291', 'B4GALT1')
# ('O60909', 'B4GALT2')
# ('O60512', 'B4GALT3')
# ('O60513', 'B4GALT4')
# ('O43286', 'B4GALT5')
# ('Q9UBX8', 'B4GALT6')
# ('Q9UBV7', 'B4GALT7')
# ('O43505', 'B4GAT1')
# ('Q9UPM9', 'B9D1')
# ('Q9BPU9', 'B9D2')
# ('Q8WXS3', 'BAALC')
# ('P0C853', 'BAALC-AS2')
# ('Q14032', 'BAAT')
# ('Q9NWV8', 'BABAM1')
# ('Q9NXR7', 'BABAM2')
# ('P56817', 'BACE1')
# ('Q9Y5Z0', 'BACE2')
# ('O14867', 'BACH1')
# ('Q9BYV9', 'BACH2')
# ('Q92934', 'BAD')
# ('Q99933', 'BAG1')
# ('O95816', 'BAG2')
# ('O95817', 'BAG3')
# ('O95429', 'BAG4')
# ('Q9UL15', 'BAG5')
# ('P46379', 'BAG6')
# ('Q13072', 'BAGE')
# ('Q86Y30', 'BAGE2')
# ('Q86Y29', 'BAGE3')
# ('Q86Y28', 'BAGE4')
# ('Q86Y27', 'BAGE5')
# ('Q9P281', 'BAHCC1')
# ('Q8TBE0', 'BAHD1')
# ('Q9UQB8', 'BAIAP2')
# ('Q9UHR4', 'BAIAP2L1')
# ('Q6UXY1', 'BAIAP2L2')
# ('O94812', 'BAIAP3')
# ('Q16611', 'BAK1')
# ('Q13145', 'BAMBI')
# ('O75531', 'BANF1')
# ('Q9H503', 'BANF2')
# ('Q8NDB2', 'BANK1')
# ('Q8N9N5', 'BANP')
# ('Q92560', 'BAP1')
# ('Q99728', 'BARD1')
# ('Q9BZE3', 'BARHL1')
# ('Q9NY43', 'BARHL2')
# ('Q9HBU1', 'BARX1')
# ('Q9UMQ3', 'BARX2')
# ('P80723', 'BASP1')
# ('Q16520', 'BATF')
# ('Q8N1L9', 'BATF2')
# ('Q9NR55', 'BATF3')
# ('Q07812', 'BAX')
# ('Q9NRL2', 'BAZ1A')
# ('Q9UIG0', 'BAZ1B')
# ('Q9UIF9', 'BAZ2A')
# ('Q9UIF8', 'BAZ2B')
# ('Q96PG8', 'BBC3')
# ('Q9BXH1', 'BBC3')
# ('A8MTZ0', 'BBIP1')
# ('Q8ND07', 'BBOF1')
# ('O75936', 'BBOX1')
# ('Q8NFJ9', 'BBS1')
# ('Q9BXC9', 'BBS2')
# ('Q96RK4', 'BBS4')
# ('Q8N3I7', 'BBS5')
# ('Q8IWZ6', 'BBS7')
# ('Q3SYG4', 'BBS9')
# ('Q8TAM1', 'BBS10')
# ('Q6ZW61', 'BBS12')
# ('Q8WY36', 'BBX')
# ('P50895', 'BCAM')
# ('Q96GW7', 'BCAN')
# ('Q9UHQ4', 'BCAP29')
# ('P51572', 'BCAP31')
# ('P56945', 'BCAR1')
# ('O75815', 'BCAR3')
# ('O75363', 'BCAS1')
# ('O75934', 'BCAS2')
# ('Q9H6U6', 'BCAS3')
# ('Q8TDM0', 'BCAS4')
# ('P54687', 'BCAT1')
# ('O15382', 'BCAT2')
# ('Q9P287', 'BCCIP')
# ('Q7Z5W3', 'BCDIN3D')
# ('P06276', 'BCHE')
# ('P12694', 'BCKDHA')
# ('P21953', 'BCKDHB')
# ('O14874', 'BCKDK')
# ('P10415', 'BCL2')
# ('Q16548', 'BCL2A1')
# ('Q07817', 'BCL2L1')
# ('Q92843', 'BCL2L2-PABPN1')
# ('Q9HD36', 'BCL2L10')
# ('O43521', 'BCL2L11')
# ('Q9HB09', 'BCL2L12')
# ('Q9BXK5', 'BCL2L13')
# ('Q9BZR8', 'BCL2L14')
# ('Q5TBC7', 'BCL2L15')
# ('P20749', 'BCL3')
# ('P41182', 'BCL6')
# ('Q8N143', 'BCL6B')
# ('Q4VC05', 'BCL7A')
# ('Q9BQE9', 'BCL7B')
# ('Q8WUZ0', 'BCL7C')
# ('O00512', 'BCL9')
# ('Q86UU0', 'BCL9L')
# ('O95999', 'BCL10')
# ('Q9H165', 'BCL11A')
# ('Q9C0K0', 'BCL11B')
# ('Q9NYF8', 'BCLAF1')
# ('A2AJT9', 'BCLAF3')
# ('Q9HAY6', 'BCO1')
# ('Q9BYV7', 'BCO2')
# ('Q6W2J9', 'BCOR')
# ('Q5H9F3', 'BCORL1')
# ('Q8N888', 'BCORP1')
# ('P11274', 'BCR')
# ('Q9Y276', 'BCS1L')
# ('Q02338', 'BDH1')
# ('Q9BUT1', 'BDH2')
# ('P46663', 'BDKRB1')
# ('P30411', 'BDKRB2')
# ('P23560', 'BDNF')
# ('A6H8Y1', 'BDP1')
# ('Q3B7T3', 'BEAN1')
# ('Q14457', 'BECN1')
# ('A8MW95', 'BECN2')
# ('Q9BUH8', 'BEGAIN')
# ('Q8NDZ0', 'BEND2')
# ('Q5T5X7', 'BEND3')
# ('Q6ZU67', 'BEND4')
# ('Q7L4P6', 'BEND5')
# ('Q5SZJ8', 'BEND6')
# ('Q8N7W2', 'BEND7')
# ('O76090', 'BEST1')
# ('Q8NFU1', 'BEST2')
# ('Q8N1M1', 'BEST3')
# ('Q8NFU0', 'BEST4')
# ('O15155', 'BET1')
# ('Q9NYM9', 'BET1L')
# ('Q9HBH7', 'BEX1')
# ('Q9BXY8', 'BEX2')
# ('Q00994', 'BEX3')
# ('Q9NWD9', 'BEX4')
# ('Q5H9J7', 'BEX5')
# ('Q9NZS9', 'BFAR')
# ('Q12934', 'BFSP1')
# ('Q13515', 'BFSP2')
# ('P02818', 'BGLAP')
# ('P21810', 'BGN')
# ('Q7RTU4', 'BHLHA9')
# ('Q7RTS1', 'BHLHA15')
# ('Q6PI77', 'BHLHB9')
# ('Q8NFJ8', 'BHLHE22')
# ('Q8NDY6', 'BHLHE23')
# ('O14503', 'BHLHE40')
# ('Q9C0J9', 'BHLHE41')
# ('C9JSJ3', 'BHMG1')
# ('Q93088', 'BHMT')
# ('Q9H2M3', 'BHMT2')
# ('Q9H694', 'BICC1')
# ('Q96G01', 'BICD1')
# ('Q8TD16', 'BICD2')
# ('Q6ZP65', 'BICDL1')
# ('A1A5D9', 'BICDL2')
# ('Q9NZM4', 'BICRA')
# ('Q6AI39', 'BICRAL')
# ('P55957', 'BID')
# ('Q13323', 'BIK')
# ('O00499', 'BIN1')
# ('Q9UBW5', 'BIN2')
# ('Q9NQY0', 'BIN3')
# ('Q13490', 'BIRC2')
# ('Q13489', 'BIRC3')
# ('O15392', 'BIRC5')
# ('Q9NR09', 'BIRC6')
# ('Q96CA5', 'BIRC7')
# ('Q96P09', 'BIRC8')
# ('Q86UB2', 'BIVM')
# ('A4D250', 'BLACE')
# ('P62952', 'BLCAP')
# ('Q8IZY5', 'BLID')
# ('P51451', 'BLK')
# ('P54132', 'BLM')
# ('Q13867', 'BLMH')
# ('Q8WV28', 'BLNK')
# ('P78537', 'BLOC1S1')
# ('Q6QNY1', 'BLOC1S2')
# ('Q6QNY0', 'BLOC1S3')
# ('Q9NUP1', 'BLOC1S4')
# ('Q8TDH9', 'BLOC1S5')
# ('Q9UL45', 'BLOC1S6')
# ('P53004', 'BLVRA')
# ('P30043', 'BLVRB')
# ('Q9H2G9', 'BLZF1')
# ('Q96MC5', 'BMERB1')
# ('Q96LC9', 'BMF')
# ('P35226', 'BMI1')
# ('P13497', 'BMP1')
# ('P12643', 'BMP2')
# ('Q9NSY1', 'BMP2K')
# ('Q5H9B9', 'BMP2KL')
# ('P12645', 'BMP3')
# ('P12644', 'BMP4')
# ('P22003', 'BMP5')
# ('P22004', 'BMP6')
# ('P18075', 'BMP7')
# ('Q7Z5Y6', 'BMP8A')
# ('P34820', 'BMP8B')
# ('O95393', 'BMP10')
# ('O95972', 'BMP15')
# ('Q8N8U9', 'BMPER')
# ('P36894', 'BMPR1A')
# ('O00238', 'BMPR1B')
# ('Q13873', 'BMPR2')
# ('Q14692', 'BMS1')
# ('Q1RMZ1', 'BMT2')
# ('P51813', 'BMX')
# ('Q01954', 'BNC1')
# ('Q6ZN30', 'BNC2')
# ('Q12981', 'BNIP1')
# ('Q12982', 'BNIP2')
# ('Q12983', 'BNIP3')
# ('O60238', 'BNIP3L')
# ('P0C671', 'BNIP5')
# ('Q7Z465', 'BNIPL')
# ('Q9BWV1', 'BOC')
# ('Q96IK1', 'BOD1')
# ('Q8NFC6', 'BOD1L1')
# ('Q8IYS8', 'BOD1L2')
# ('Q9UMX3', 'BOK')
# ('Q9Y3E2', 'BOLA1')
# ('Q9H3K6', 'BOLA2B')
# ('Q53S33', 'BOLA3')
# ('Q8N9W6', 'BOLL')
# ('Q14137', 'BOP1')
# ('Q6PGQ7', 'BORA')
# ('Q969J3', 'BORCS5')
# ('Q96GS4', 'BORCS6')
# ('Q96B45', 'BORCS7')
# ('Q96FH0', 'BORCS8')
# ('Q9GZL8', 'BPESC1')
# ('P07738', 'BPGM')
# ('Q86WA6', 'BPHL')
# ('P17213', 'BPI')
# ('Q9NP55', 'BPIFA1')
# ('Q96DR5', 'BPIFA2')
# ('Q9BQP9', 'BPIFA3')
# ('Q86YQ2', 'BPIFA4P')
# ('Q8TDL5', 'BPIFB1')
# ('Q8N4F0', 'BPIFB2')
# ('P59826', 'BPIFB3')
# ('P59827', 'BPIFB4')
# ('Q8NFQ5', 'BPIFB6')
# ('Q8NFQ6', 'BPIFC')
# ('O95861', 'BPNT1')
# ('Q9NX62', 'BPNT2')
# ('Q12830', 'BPTF')
# ('O14599', 'BPY2C')
# ('P15056', 'BRAF')
# ('Q7Z569', 'BRAP')
# ('Q6PJG6', 'BRAT1')
# ('P38398', 'BRCA1')
# ('P51587', 'BRCA2')
# ('P46736', 'BRCC3')
# ('O95696', 'BRD1')
# ('P25440', 'BRD2')
# ('Q15059', 'BRD3')
# ('A0A1B0GUI7', 'BRD3OS')
# ('O60885', 'BRD4')
# ('Q9NPI1', 'BRD7')
# ('Q9H0E9', 'BRD8')
# ('Q9H8M2', 'BRD9')
# ('Q58F21', 'BRDT')
# ('Q92994', 'BRF1')
# ('Q9HAW0', 'BRF2')
# ('O95415', 'BRI3')
# ('Q8WY22', 'BRI3BP')
# ('Q6PL45', 'BRICD5')
# ('O60477', 'BRINP1')
# ('Q9C0B6', 'BRINP2')
# ('Q76B58', 'BRINP3')
# ('Q9BX63', 'BRIP1')
# ('Q8TDN6', 'BRIX1')
# ('Q8WUW1', 'BRK1')
# ('Q9HCU9', 'BRMS1')
# ('Q5PSV4', 'BRMS1L')
# ('Q5VW32', 'BROX')
# ('P55201', 'BRPF1')
# ('Q9ULD4', 'BRPF3')
# ('P32247', 'BRS3')
# ('Q8TDC3', 'BRSK1')
# ('Q8IWQ3', 'BRSK2')
# ('Q9NSI6', 'BRWD1')
# ('P59051', 'BRWD1-AS2')
# ('Q6RI45', 'BRWD3')
# ('Q96G97', 'BSCL2')
# ('Q9NW68', 'BSDC1')
# ('P35613', 'BSG')
# ('Q9UPA5', 'BSN')
# ('Q8WZ55', 'BSND')
# ('Q075Z2', 'BSPH1')
# ('Q5W0U4', 'BSPRY')
# ('Q10588', 'BST1')
# ('Q10589', 'BST2')
# ('Q3C1V8', 'BSX')
# ('O14981', 'BTAF1')
# ('Q9H0C5', 'BTBD1')
# ('Q9BX70', 'BTBD2')
# ('Q9Y2F9', 'BTBD3')
# ('Q96KE9', 'BTBD6')
# ('Q9P203', 'BTBD7')
# ('Q5XKL5', 'BTBD8')
# ('Q96Q07', 'BTBD9')
# ('Q9BSF8', 'BTBD10')
# ('A6QL63', 'BTBD11')
# ('Q32M84', 'BTBD16')
# ('A6NE02', 'BTBD17')
# ('B2RXH4', 'BTBD18')
# ('C9JJ37', 'BTBD19')
# ('P35070', 'BTC')
# ('P43251', 'BTD')
# ('P20290', 'BTF3')
# ('Q96K17', 'BTF3L4')
# ('P62324', 'BTG1')
# ('P78543', 'BTG2')
# ('Q14201', 'BTG3')
# ('Q9NY30', 'BTG4')
# ('Q06187', 'BTK')
# ('Q7Z6A9', 'BTLA')
# ('Q13410', 'BTN1A1')
# ('Q7KYR7', 'BTN2A1')
# ('Q6ZV77', 'C9orf139')
# ('Q5JTZ5', 'C9orf152')
# ('Q5TBE3', 'C9orf153')
# ('Q8N9P6', 'C9orf163')
# ('Q8N6V4', 'C10orf53')
# ('Q5SWW7', 'C10orf55')
# ('Q5T681', 'C10orf62')
# ('Q8IYJ2', 'C10orf67')
# ('Q711Q0', 'C10orf71')
# ('Q8WW14', 'C10orf82')
# ('Q9H8K7', 'C10orf88')
# ('Q96M02', 'C10orf90')
# ('Q9H7T3', 'C10orf95')
# ('Q6UWK7', 'C10orf99')
# ('Q8TEF2', 'C10orf105')
# ('Q5SQS8', 'C10orf120')
# ('Q8N4M7', 'C10orf126')
# ('A0A1B0GUT2', 'C10orf143')
# ('Q9H5F2', 'C11orf1')
# ('Q9NQ32', 'C11orf16')
# ('Q9P2W6', 'C11orf21')
# ('Q96F05', 'C11orf24')
# ('Q8WZ69', 'C11orf40')
# ('Q8N5U0', 'C11orf42')
# ('Q8TAV5', 'C11orf45')
# ('Q9H6J7', 'C11orf49')
# ('Q96A22', 'C11orf52')
# ('Q8IXP5', 'C11orf53')
# ('Q9H0W9', 'C11orf54')
# ('O00193', 'C11orf58')
# ('Q8NCR3', 'C11orf65')
# ('Q9H3H3', 'C11orf68')
# ('Q6IPW1', 'C11orf71')
# ('Q8NBR9', 'C11orf72')
# ('Q8N6T0', 'C11orf80')
# ('A6NJI1', 'C11orf86')
# ('Q6NUJ2', 'C11orf87')
# ('Q6PI97', 'C11orf88')
# ('Q3C1V1', 'C11orf91')
# ('C9JXX5', 'C11orf94')
# ('C9JLR9', 'C11orf95')
# ('Q7Z7L8', 'C11orf96')
# ('A0A1B0GVM6', 'C11orf97')
# ('E9PRG8', 'C11orf98')
# ('Q9NQ89', 'C12orf4')
# ('Q8N999', 'C12orf29')
# ('Q86WS4', 'C12orf40')
# ('Q96LP6', 'C12orf42')
# ('Q96C57', 'C12orf43')
# ('Q8N5I9', 'C12orf45')
# ('Q9H741', 'C12orf49')
# ('Q8NA57', 'C12orf50')
# ('Q6X4T0', 'C12orf54')
# ('Q8IXR9', 'C12orf56')
# ('Q99622', 'C12orf57')
# ('Q5U649', 'C12orf60')
# ('Q9H3J6', 'C12orf65')
# ('Q96MD2', 'C12orf66')
# ('A8MTZ7', 'C12orf71')
# ('Q69YU5', 'C12orf73')
# ('Q8TAD7', 'C12orf75')
# ('Q8N812', 'C12orf76')
# ('C9JDV5', 'C12orf77')
# ('A0A1B0GVH6', 'C13orf42')
# ('A0A1B0GUA9', 'C13orf46')
# ('Q4W4Y0', 'C14orf28')
# ('Q8N1H7', 'C14orf39')
# ('Q9H972', 'C14orf93')
# ('Q9NWQ9', 'C14orf119')
# ('Q9NPU4', 'C14orf132')
# ('Q52M58', 'C14orf177')
# ('Q8N769', 'C14orf178')
# ('Q8N912', 'C14orf180')
# ('Q32M92', 'C15orf32')
# ('Q6ZRI6', 'C15orf39')
# ('Q8WUR7', 'C15orf40')
# ('Q9C002', 'C15orf48')
# ('Q8N8G6', 'C15orf54')
# ('Q8N910', 'C15orf56')
# ('Q6ZV56', 'C22orf34')
# ('Q6P5X5', 'C22orf39')
# ('Q6IC83', 'C22orf42')
# ('C9J442', 'C22orf46')
# ('P00915', 'CA1')
# ('P00918', 'CA2')
# ('P07451', 'CA3')
# ('P22748', 'CA4')
# ('P35218', 'CA5A')
# ('Q9Y2D0', 'CA5B')
# ('Q8WTZ4', 'CA5BP1')
# ('P23280', 'CA6')
# ('P43166', 'CA7')
# ('P35219', 'CA8')
# ('Q16790', 'CA9')
# ('Q9NS85', 'CA10')
# ('O75493', 'CA11')
# ('O43570', 'CA12')
# ('Q8N1Q1', 'CA13')
# ('Q9ULX7', 'CA14')
# ('Q9H8G2', 'CAAP1')
# ('Q9Y376', 'CAB39')
# ('Q9H9S4', 'CAB39L')
# ('Q8IVU9', 'CABCOCO1')
# ('Q9Y6J0', 'CABIN1')
# ('Q8TDN4', 'CABLES1')
# ('Q9BTV7', 'CABLES2')
# ('Q9NZU7', 'CABP1')
# ('Q9NPB3', 'CABP2')
# ('P57796', 'CABP4')
# ('Q9NP86', 'CABP5')
# ('Q86V35', 'CABP7')
# ('Q96KC9', 'CABS1')
# ('O75952', 'CABYR')
# ('Q9UGQ2', 'CACFD1')
# ('Q5VU97', 'CACHD1')
# ('O00555', 'CACNA1A')
# ('Q00975', 'CACNA1B')
# ('Q13936', 'CACNA1C')
# ('Q01668', 'CACNA1D')
# ('Q15878', 'CACNA1E')
# ('O60840', 'CACNA1F')
# ('O43497', 'CACNA1G')
# ('O95180', 'CACNA1H')
# ('Q9P0X4', 'CACNA1I')
# ('Q13698', 'CACNA1S')
# ('P54289', 'CACNA2D1')
# ('Q9NY47', 'CACNA2D2')
# ('Q8IZS8', 'CACNA2D3')
# ('Q7Z3S7', 'CACNA2D4')
# ('Q02641', 'CACNB1')
# ('Q08289', 'CACNB2')
# ('P54284', 'CACNB3')
# ('O00305', 'CACNB4')
# ('Q06432', 'CACNG1')
# ('Q9Y698', 'CACNG2')
# ('O60359', 'CACNG3')
# ('Q9UBN1', 'CACNG4')
# ('Q9UF02', 'CACNG5')
# ('Q9BXT2', 'CACNG6')
# ('P62955', 'CACNG7')
# ('Q8WXS5', 'CACNG8')
# ('Q8WUQ7', 'CACTIN')
# ('Q8N1I8', 'CACTIN-AS1')
# ('Q86Y37', 'CACUL1')
# ('Q9HB71', 'CACYBP')
# ('P27708', 'CAD')
# ('Q9BY67', 'CADM1')
# ('Q8N3J6', 'CADM2')
# ('Q8N126', 'CADM3')
# ('Q8NFZ8', 'CADM4')
# ('Q9ULU8', 'CADPS')
# ('Q86UW7', 'CADPS2')
# ('Q8TC20', 'CAGE1')
# ('P05937', 'CALB1')
# ('P22676', 'CALB2')
# ('P01258', 'CALCA')
# ('P06881', 'CALCA')
# ('P10092', 'CALCB')
# ('Q9P1Z2', 'CALCOCO1')
# ('Q13137', 'CALCOCO2')
# ('P30988', 'CALCR')
# ('Q16602', 'CALCRL')
# ('Q05682', 'CALD1')
# ('Q8IU99', 'CALHM1')
# ('Q9HA72', 'CALHM2')
# ('Q86XJ0', 'CALHM3')
# ('Q5JW98', 'CALHM4')
# ('Q8N5C1', 'CALHM5')
# ('Q5R3K3', 'CALHM6')
# ('P0DP23', 'CALM1')
# ('P0DP24', 'CALM2')
# ('P0DP25', 'CALM3')
# ('P27482', 'CALML3')
# ('Q96GE6', 'CALML4')
# ('Q9NZT1', 'CALML5')
# ('Q8TD86', 'CALML6')
# ('Q9BXU9', 'CALN1')
# ('P27797', 'CALR')
# ('Q96L12', 'CALR3')
# ('O43852', 'CALU')
# ('Q9NYX4', 'CALY')
# ('Q14012', 'CAMK1')
# ('Q8IU85', 'CAMK1D')
# ('Q96NX5', 'CAMK1G')
# ('Q9UQM7', 'CAMK2A')
# ('Q13554', 'CAMK2B')
# ('Q13557', 'CAMK2D')
# ('Q13555', 'CAMK2G')
# ('Q7Z7J9', 'CAMK2N1')
# ('Q96S95', 'CAMK2N2')
# ('Q16566', 'CAMK4')
# ('Q8N5S9', 'CAMKK1')
# ('Q96RR4', 'CAMKK2')
# ('Q7Z624', 'CAMKMT')
# ('Q8NCB2', 'CAMKV')
# ('P49069', 'CAMLG')
# ('P49913', 'CAMP')
# ('Q5T5Y3', 'CAMSAP1')
# ('Q08AD1', 'CAMSAP2')
# ('Q9P1Y5', 'CAMSAP3')
# ('Q9Y6Y1', 'CAMTA1')
# ('O94983', 'CAMTA2')
# ('Q86VP6', 'CAND1')
# ('O75155', 'CAND2')
# ('Q8WVQ1', 'CANT1')
# ('P27824', 'CANX')
# ('Q01518', 'CAP1')
# ('P40123', 'CAP2')
# ('P40121', 'CAPG')
# ('P07384', 'CAPN1')
# ('P17655', 'CAPN2')
# ('P20807', 'CAPN3')
# ('O15484', 'CAPN5')
# ('Q9Y6Q1', 'CAPN6')
# ('Q9Y6W3', 'CAPN7')
# ('A6NHC0', 'CAPN8')
# ('O14815', 'CAPN9')
# ('Q9HC96', 'CAPN10')
# ('Q9UMQ6', 'CAPN11')
# ('Q6ZSI9', 'CAPN12')
# ('Q6MZZ7', 'CAPN13')
# ('A8MX76', 'CAPN14')
# ('O75808', 'CAPN15')
# ('P04632', 'CAPNS1')
# ('Q96L46', 'CAPNS2')
# ('Q14444', 'CAPRIN1')
# ('Q6IMN6', 'CAPRIN2')
# ('Q13938', 'CAPS')
# ('Q9BXY5', 'CAPS2')
# ('Q8WWF8', 'CAPSL')
# ('P52907', 'CAPZA1')
# ('P47755', 'CAPZA2')
# ('Q96KX2', 'CAPZA3')
# ('P47756', 'CAPZB')
# ('Q9BX69', 'CARD6')
# ('Q9Y2G2', 'CARD8')
# ('Q9H257', 'CARD9')
# ('Q9BWT7', 'CARD10')
# ('Q9BXL7', 'CARD11')
# ('Q9BXL6', 'CARD14')
# ('Q5EG05', 'CARD16')
# ...
# ('Q5TFG8', 'ZC2HC1B')
# ('Q53FD0', 'ZC2HC1C')
# ('Q8IXZ2', 'ZC3H3')
# ('Q9UPT8', 'ZC3H4')
# ('P61129', 'ZC3H6')
# ('Q8IWR0', 'ZC3H7A')
# ('Q9UGR2', 'ZC3H7B')
# ('Q8N5P1', 'ZC3H8')
# ('Q96K80', 'ZC3H10')
# ('O75152', 'ZC3H11A')
# ('A0A1B0GTU1', 'ZC3H11B')
# ('Q5D1E8', 'ZC3H12A')
# ('Q5HYM0', 'ZC3H12B')
# ('Q9C0D7', 'ZC3H12C')
# ('A2A288', 'ZC3H12D')
# ('Q5T200', 'ZC3H13')
# ('Q6PJT7', 'ZC3H14')
# ('Q8WU90', 'ZC3H15')
# ('Q86VM9', 'ZC3H18')
# ('Q7Z2W4', 'ZC3HAV1')
# ('Q96H79', 'ZC3HAV1L')
# ('Q86WB0', 'ZC3HC1')
# ('Q9NQZ6', 'ZC4H2')
# ('Q9C0B9', 'ZCCHC2')
# ('Q9NUD5', 'ZCCHC3')
# ('Q9H5U6', 'ZCCHC4')
# ('Q8N3Z6', 'ZCCHC7')
# ('Q6NZY4', 'ZCCHC8')
# ('Q8N567', 'ZCCHC9')
# ('Q8TBK6', 'ZCCHC10')
# ('Q6PEW1', 'ZCCHC12')
# ('Q8WW36', 'ZCCHC13')
# ('Q8WYQ9', 'ZCCHC14')
# ('Q9NP64', 'ZCCHC17')
# ('P0CG32', 'ZCCHC18')
# ('Q8N2G6', 'ZCCHC24')
# ('Q8TBF4', 'ZCRB1')
# ('Q9H0M4', 'ZCWPW1')
# ('Q504Y3', 'ZCWPW2')
# ('Q9HCK1', 'ZDBF2')
# ('Q8WTX9', 'ZDHHC1')
# ('Q9UIJ5', 'ZDHHC2')
# ('Q9NYG2', 'ZDHHC3')
# ('Q9NPG8', 'ZDHHC4')
# ('Q9C0B5', 'ZDHHC5')
# ('Q9H6R6', 'ZDHHC6')
# ('Q9NXF8', 'ZDHHC7')
# ('Q9ULC8', 'ZDHHC8')
# ('Q9Y397', 'ZDHHC9')
# ('Q9H8X9', 'ZDHHC11')
# ('P0C7U3', 'ZDHHC11B')
# ('Q96GR4', 'ZDHHC12')
# ('Q8IUH4', 'ZDHHC13')
# ('Q8IZN3', 'ZDHHC14')
# ('Q96MV8', 'ZDHHC15')
# ('Q969W1', 'ZDHHC16')
# ('Q8IUH5', 'ZDHHC17')
# ('Q9NUE0', 'ZDHHC18')
# ('Q8WVZ1', 'ZDHHC19')
# ('Q5W0Z9', 'ZDHHC20')
# ('Q8IVQ6', 'ZDHHC21')
# ('Q8N966', 'ZDHHC22')
# ('Q8IYP9', 'ZDHHC23')
# ('Q6UX98', 'ZDHHC24')
# ('P37275', 'ZEB1')
# ('O60315', 'ZEB2')
# ('Q7Z7L7', 'ZER1')
# ('Q8TCF1', 'ZFAND1')
# ('Q8N6M9', 'ZFAND2A')
# ('Q8WV99', 'ZFAND2B')
# ('Q9H8U3', 'ZFAND3')
# ('Q86XD8', 'ZFAND4')
# ('O76080', 'ZFAND5')
# ('Q6FIF0', 'ZFAND6')
# ('Q9P243', 'ZFAT')
# ('O60293', 'ZFC3H1')
# ('Q9C0A1', 'ZFHX2')
# ('Q15911', 'ZFHX3')
# ('Q86UP3', 'ZFHX4')
# ('Q6P2D0', 'ZFP1')
# ('Q6ZN57', 'ZFP2')
# ('Q96NJ6', 'ZFP3')
# ('Q9HCL3', 'ZFP14')
# ('Q8NHY6', 'ZFP28')
# ('Q9Y2G7', 'ZFP30')
# ('P26651', 'ZFP36')
# ('Q07352', 'ZFP36L1')
# ('P47974', 'ZFP36L2')
# ('Q9Y6Q3', 'ZFP37')
# ('Q8N8Y5', 'ZFP41')
# ('Q96MM3', 'ZFP42')
# ('Q9NU63', 'ZFP57')
# ('Q8NB50', 'ZFP62')
# ('Q9NTW7', 'ZFP64')
# ('Q49AA0', 'ZFP69')
# ('Q9UJL9', 'ZFP69B')
# ('Q8N141', 'ZFP82')
# ('Q8TF47', 'ZFP90')
# ('Q96JP5', 'ZFP91')
# ('A6NM28', 'ZFP92')
# ('O95159', 'ZFPL1')
# ('Q8IX07', 'ZFPM1')
# ('Q8WW38', 'ZFPM2')
# ('Q96KR1', 'ZFR')
# ('Q9UPR6', 'ZFR2')
# ('P17010', 'ZFX')
# ('P08048', 'ZFY')
# ('Q9HBF4', 'ZFYVE1')
# ('O95405', 'ZFYVE9')
# ('Q7Z3T8', 'ZFYVE16')
# ('Q96K21', 'ZFYVE19')
# ('Q9BQ24', 'ZFYVE21')
# ('Q68DK2', 'ZFYVE26')
# ('Q5T4F4', 'ZFYVE27')
# ('Q9HCC9', 'ZFYVE28')
# ('O60844', 'ZG16')
# ('Q96DA0', 'ZG16B')
# ('P0C6A0', 'ZGLP1')
# ('Q8N5A5', 'ZGPAT')
# ('Q86YA3', 'ZGRF1')
# ('Q9UKY1', 'ZHX1')
# ('Q96EF9', 'ZHX1-C8orf76')
# ('Q9Y6X8', 'ZHX2')
# ('Q9H4I2', 'ZHX3')
# ('Q15915', 'ZIC1')
# ('O95409', 'ZIC2')
# ('O60481', 'ZIC3')
# ('Q8N9L1', 'ZIC4')
# ('Q96T25', 'ZIC5')
# ('Q3SY52', 'ZIK1')
# ('Q9NZV7', 'ZIM2')
# ('Q96PE6', 'ZIM3')
# ('P17029', 'ZKSCAN1')
# ('Q63HK3', 'ZKSCAN2')
# ('Q9BRR0', 'ZKSCAN3')
# ('Q969J2', 'ZKSCAN4')
# ('Q9Y2L8', 'ZKSCAN5')
# ('Q9P0L1', 'ZKSCAN7')
# ('Q15776', 'ZKSCAN8')
# ('Q5H9K5', 'ZMAT1')
# ('Q96NC0', 'ZMAT2')
# ('Q9HA38', 'ZMAT3')
# ('Q9H898', 'ZMAT4')
# ('Q9UDW3', 'ZMAT5')
# ('Q9ULJ6', 'ZMIZ1')
# ('Q8NF64', 'ZMIZ2')
# ('O75844', 'ZMPSTE24')
# ('Q5SVZ6', 'ZMYM1')
# ('Q9UBW7', 'ZMYM2')
# ('Q14202', 'ZMYM3')
# ('Q5VZL5', 'ZMYM4')
# ('Q9UJ78', 'ZMYM5')
# ('O95789', 'ZMYM6')
# ('Q9ULU4', 'ZMYND8')
# ('O75800', 'ZMYND10')
# ('Q15326', 'ZMYND11')
# ('Q9H0C1', 'ZMYND12')
# ('Q9H091', 'ZMYND15')
# ('Q96E35', 'ZMYND19')
# ('Q9BSG1', 'ZNF2')
# ('Q96GE5', 'ZNF799')
# ('Q2TB10', 'ZNF800')
# ('Q7Z570', 'ZNF804A')
# ('A4D1E1', 'ZNF804B')
# ('Q5CZA5', 'ZNF805')
# ('P0C7X5', 'ZNF806')
# ('Q8N4W9', 'ZNF808')
# ('Q6ZN06', 'ZNF813')
# ('B7Z6K7', 'ZNF814')
# ('A8K554', 'ZNF815P')
# ('Q0VGE8', 'ZNF816')
# ('Q6ZRF7', 'ZNF818P')
# ('O75541', 'ZNF821')
# ('P16415', 'ZNF823')
# ('Q6ZT77', 'ZNF826P')
# ('Q17R98', 'ZNF827')
# ('Q3KNS6', 'ZNF829')
# ('Q96NB3', 'ZNF830')
# ('Q5JPB2', 'ZNF831')
# ('Q6ZTB9', 'ZNF833P')
# ('Q9Y2P0', 'ZNF835')
# ('Q6ZNA1', 'ZNF836')
# ('Q96EG3', 'ZNF837')
# ('A8K0R7', 'ZNF839')
# ('A6NDX5', 'ZNF840P')
# ('Q6ZN19', 'ZNF841')
# ('Q8N446', 'ZNF843')
# ('Q08AG5', 'ZNF844')
# ('Q96IR2', 'ZNF845')
# ('Q147U1', 'ZNF846')
# ('A8MQ14', 'ZNF850')
# ('Q6ZMS4', 'ZNF852')
# ('P0CG23', 'ZNF853')
# ('A6NHJ4', 'ZNF860')
# ('O60384', 'ZNF861P')
# ('O60290', 'ZNF862')
# ('P0CJ78', 'ZNF865')
# ('P10072', 'ZNF875')
# ('Q49A33', 'ZNF876P')
# ('C9JN71', 'ZNF878')
# ('B4DU55', 'ZNF879')
# ('Q6PDB4', 'ZNF880')
# ('P0CG24', 'ZNF883')
# ('P0CJ79', 'ZNF888')
# ('A8MT65', 'ZNF891')
# ('Q9P2E3', 'ZNFX1')
# ('O43257', 'ZNHIT1')
# ('Q9UHR6', 'ZNHIT2')
# ('Q15649', 'ZNHIT3')
# ('Q9NWK9', 'ZNHIT6')
# ('O60232', 'ZNRD2')
# ('Q8ND25', 'ZNRF1')
# ('Q8NHG8', 'ZNRF2')
# ('Q9ULT6', 'ZNRF3')
# ('Q8WWF5', 'ZNRF4')
# ('P60852', 'ZP1')
# ('Q05996', 'ZP2')
# ('P21754', 'ZP3')
# ('Q12836', 'ZP4')
# ('Q9BS86', 'ZPBP')
# ('Q6X784', 'ZPBP2')
# ('Q8TCW7', 'ZPLD1')
# ('O75312', 'ZPR1')
# ('Q9UGI0', 'ZRANB1')
# ('O95218', 'ZRANB2')
# ('Q5FWF4', 'ZRANB3')
# ('Q15696', 'ZRSR2')
# ('Q15695', 'ZRSR2P1')
# ('Q8NBB4', 'ZSCAN1')
# ('Q7Z7L9', 'ZSCAN2')
# ('Q8NAM6', 'ZSCAN4')
# ('Q9BUG6', 'ZSCAN5A')
# ('A6NJL1', 'ZSCAN5B')
# ('A6NGD5', 'ZSCAN5C')
# ('P0CG00', 'ZSCAN5DP')
# ('O15535', 'ZSCAN9')
# ('Q96SZ4', 'ZSCAN10')
# ('O43309', 'ZSCAN12')
# ('Q9H4T2', 'ZSCAN16')
# ('Q8TBC5', 'ZSCAN18')
# ('P17040', 'ZSCAN20')
# ('Q9Y5A6', 'ZSCAN21')
# ('P10073', 'ZSCAN22')
# ('Q3MJ62', 'ZSCAN23')
# ('Q6NSZ9', 'ZSCAN25')
# ('Q16670', 'ZSCAN26')
# ('Q8IWY8', 'ZSCAN29')
# ('Q86W11', 'ZSCAN30')
# ('Q96LW9', 'ZSCAN31')
# ('Q9NX65', 'ZSCAN32')
# ('Q9BR11', 'ZSWIM1')
# ('Q8NEG5', 'ZSWIM2')
# ('Q96MP5', 'ZSWIM3')
# ('Q9H7M6', 'ZSWIM4')
# ('Q9P217', 'ZSWIM5')
# ('Q9HCJ5', 'ZSWIM6')
# ('Q19AV6', 'ZSWIM7')
# ('A7E2V4', 'ZSWIM8')
# ('Q86XI8', 'ZSWIM9')
# ('Q96AP4', 'ZUP1')
# ('O43264', 'ZW10')
# ('Q9H900', 'ZWILCH')
# ('O95229', 'ZWINT')
# ('P98168', 'ZXDA')
# ('P98169', 'ZXDB')
# ('Q2QGD7', 'ZXDC')
# ('Q6WRX3', 'ZYG11A')
# ('Q9C0D3', 'ZYG11B')
# ('Q15942', 'ZYX')
# ('O43149', 'ZZEF1')
# ('Q8IYH5', 'ZZZ3')

# %%
# Write usefull columns of intact
# file to dataframe:
with open(intact_file) as intact:
    intact_df = pd.read_table(intact,
                            usecols = ['#ID(s) interactor A',
                                       'ID(s) interactor B',
                                       'Alias(es) interactor A',
                                       'Alias(es) interactor B',
                                      'Publication Identifier(s)',
                                      'Confidence value(s)',
                                      'Taxid interactor A',
                                      'Taxid interactor B',
                                      'Type(s) interactor A',
                                      'Type(s) interactor B'],
                            dtype = str)
intact_df.columns = ['A_uni', 'B_uni', 'A', 'B', 'Ref', 'Tax_A', 'Tax_B', 'Conf_val', 'Type_A', 'Type_B']

# Select interactions that are
# human-human, protein-protein
# and have a confidence value > 0.4.
corr_taxon = 'taxid:9606(human)|taxid:9606(Homo sapiens)'
intact_df = intact_df.loc[(intact_df['Tax_A'] == corr_taxon) & (intact_df['Tax_B'] == corr_taxon)].drop_duplicates()

corr_type = 'psi-mi:"MI:0326"(protein)'
intact_df = intact_df.loc[(intact_df['Type_A'] == corr_type) & (intact_df['Type_B'] == corr_type)].drop_duplicates()

intact_df['Conf_val'] = intact_df['Conf_val'].map(lambda x: float(x[-4:]))
intact_df = intact_df.loc[intact_df['Conf_val'] > 0.40]

# 
def uniprot_hugo(some_str):
    method_obj = re.search(r'[OPQ][0-9][A-Z0-9]{3}[0-9]|[A-NR-Z][0-9]([A-Z][A-Z0-9]{2}[0-9]){1,2}', some_str)
    if method_obj == None:
        return np.NaN
    else:
        uni_id = method_obj.group(0)
        if uni_id in hugo_uniprot_dict.keys():
            return hugo_uniprot_dict[uni_id]
        else:
            return np.NaN

def filter_hugo(some_str):
    list_str = some_str.split('|')
    for index, element in enumerate(list_str):
        if '(gene name)' in element:
            gene_name = element[10:-11]
            break
        elif index + 1 == len(list_str):
            gene_name = np.NaN
    return gene_name
        
intact_df[['A', 'B']] = intact_df[['A', 'B']].applymap(filter_hugo)
intact_df[['A_uni', 'B_uni']] = intact_df[['A_uni', 'B_uni']].applymap(uniprot_hugo)

intact_df['A_'] = [x if (type(x) == str) else y if isinstance(y, str) else 'No gene name' for x, y in zip(list(intact_df['A_uni']), list(intact_df['A']))]
intact_df['B_'] = [x if (type(x) == str) else y if isinstance(y, str) else 'No gene name' for x, y in zip(list(intact_df['B_uni']), list(intact_df['B']))]

intact_df = intact_df.loc[:, ['A_', 'B_', 'Ref', 'Conf_val']].rename(columns = {'A_':'A', 'B_':'B'})

def filter_pmid(some_str):
    method_obj = re.search(r'(?<=pubmed:)[0-9]+', some_str)
    if method_obj == None:
        return np.NaN
    else:
        return method_obj.group(0)

intact_df['PMID'] = intact_df['Ref'].map(filter_pmid)
intact_df.drop(columns = 'Ref', inplace = True)

new_rows = []
for index, row in intact_df.iterrows():
    a = row['A']
    b = row['B']
    if a > b:
        row['A'] = b
        row['B'] = a
    new_rows.append(row)
intact_df = pd.DataFrame(new_rows)

intact_a_tf = intact_df.loc[intact_df['A'].isin(tfs)].copy()
intact_a_tf_copy = intact_a_tf.groupby(['A', 'B']).nunique()

intact_b_tf = intact_df.loc[intact_df['B'].isin(tfs)].copy()
intact_b_tf_copy = intact_b_tf.groupby(['A', 'B']).nunique()

tf_int_list_a = [[index[0], index[1]] for index, row in intact_a_tf_copy.iterrows()]
tf_int_list_b = [[index[0], index[1]] for index, row in intact_b_tf_copy.iterrows()]

int_dict = {}
for i in tf_int_list_a:
    tf = i[0]
    interactor = i[1]
    df = intact_a_tf.loc[(intact_a_tf['A'] == tf) & (intact_a_tf['B'] == interactor)]
    pmids = [str(x) for x in set(df['PMID']) if str(x) != 'nan']
    newlist = [tf, ', '.join(pmids), set(df['Conf_val'])]
    if not interactor in int_dict.keys():
        int_dict[interactor] = [newlist]
    else:
        int_dict[interactor].append(newlist)

for i in tf_int_list_b:
    tf = i[1]
    interactor = i[0]
    df = intact_b_tf.loc[(intact_b_tf['B'] == tf) & (intact_b_tf['A'] == interactor)]
    pmids = [str(x) for x in set(df['PMID']) if str(x) != 'nan']
    newlist = [tf, ', '.join(pmids), set(df['Conf_val'])]
    if not interactor in int_dict.keys():
        int_dict[interactor] = [newlist]
    else:
        int_dict[interactor].append(newlist)
        
constructlist = []
for interactor, interactions in int_dict.items():
    for interaction in interactions:
        tf, pmids, conf_val = (interaction[i] for i in range(len(interaction)))
        constructlist.append([interactor, tf, pmids, list(conf_val)[0]])

interactors_intact = pd.DataFrame(constructlist, columns = ['Interactor', 'TF', 'PMIDS', 'Confidence Value'])#.set_index('Interactor')
interactors_intact = interactors_intact.sort_values(by = ['Interactor', 'TF'])

intact_interactors = set(interactors_intact['Interactor'])
newrows = []
for interactor in intact_interactors:
    df = interactors_intact.loc[interactors_intact['Interactor'] == interactor]
    interacting_tfs = list(df['TF'])
    newrow = [interactor, ', '.join(interacting_tfs)]
    newrows.append(newrow)

interactors_intact_simple = pd.DataFrame(newrows, columns = ['Interactor', 'TFs'])
interactors_intact_simple = interactors_intact_simple.sort_values(by = ['Interactor', 'TFs'])

with open(tf_smallset_file) as tfs_small:
    tfs_small_set = set([x.strip() for x in tfs_small])
    new_col = []
    for index, row in interactors_intact_simple.iterrows():
        tfs = row['TFs'].split(', ')
        
        if any(x in tfs_small_set for x in tfs):
            new_col.append(1)
        else:
            new_col.append(0)
    interactors_intact_simple['Interaction with small set of TFs'] = new_col
    
interactors_intact.to_csv(folder_output + '04_tf_interactors_intact.csv', index = False)
interactors_intact_simple.to_csv(folder_output + '05_tf_interactors_intact_simple.csv', index = False)

print(len(set(interactors_intact['Interactor'])))
print(interactors_intact.head())
print('\n')
interactors_intact_simple
# Out:
# 4262
#                      Interactor       TF               PMIDS  Confidence Value
# 10849  "WUGSC:H_DJ0726N20.gs.b"    MEOX2                                  0.56
# 10850                      A1CF      REL            25416956              0.56
# 10851                      AAMP  BHLHE40            25416956              0.56
# 10852                     AANAT  BHLHE40  25910212, 25416956              0.72
# 10853                  AASDHPPT      CRX                                  0.56
#                     Interactor  \
# 653   "WUGSC:H_DJ0726N20.gs.b"
# 4150                      A1CF
# 3061                      AAMP
# 3462                     AANAT
# 172                   AASDHPPT
# 4125                      AATF
# 1933                     ABCA1
# 1840                     ABCC2
# 2342                     ABCF3
# 3727                    ABHD11
# 2717                   ABHD16A
# 212                       ABI1
# 1927                      ABI2
# 3875                      ABL1
# 1457                      ABL2
# 206                     ABLIM3
# 857                      ACAA1
# 3937                     ACACA
# 1574                     ACAT2
# 1854                     ACBD4
# 3781                      ACHE
# 3071                    ACOT12
# 3758                     ACOT7
# 3423                     ACOT8
# 924                      ACSF2
# 3683                     ACSL6
# 2109                     ACSS1
# 373                       ACTB
# 1302                     ACTC1
# 3397                    ACTL6A
# ...                        ...
# 3104                     ZNF79
# 1539                    ZNF792
# 197                       ZNF8
# 2350                    ZNF829
# 258                     ZNF835
# 3766                    ZNF837
# 3843                    ZNF843
# 747                      ZNF85
# 847                      ZNF92
# 822                     ZNHIT1
# 1572                     ZNRF4
# 1719                    ZRANB1
# 3435                    ZSCAN1
# 138                    ZSCAN12
# 687                    ZSCAN16
# 2421                   ZSCAN18
# 2602                   ZSCAN20
# 3450                   ZSCAN21
# 3437                   ZSCAN22
# 1426                   ZSCAN23
# 276                    ZSCAN25
# 3653                   ZSCAN29
# 2270                   ZSCAN30
# 812                    ZSCAN32
# 3531                   ZSCAN5B
# 3372                    ZSCAN9
# 264                     ZSWIM9
# 674                      ZWINT
# 2970                      ZXDB
# 2168                       ZYX
#
#                                                     TFs  \
# 653                                               MEOX2
# 4150                                                REL
# 3061                                            BHLHE40
# 3462                                            BHLHE40
# 172                                                 CRX
# 4125                                          RELA, SP1
# 1933                                              NR1H2
# 1840                                              NFKB1
# 2342                                              THAP1
# 3727                   PATZ1, PITX1, PROP1, VENTX, ZIC1
# 2717                                              CREB3
# 212                                                HHEX
# 1927  CRX, EGR4, FOXD4L1, HHEX, LHX3, LHX8, MEOX2, M...
# 3875                                         AR, STAT5A
# 1457                                          AR, STAT3
# 206                                       IKZF3, ZNF620
# 857                                               TFCP2
# 3937                                                MYC
# 1574                                              ZNF76
# 1854                             CRX, MEOX1, MEOX2, REL
# 3781                                               ENO1
# 3071              MEOX1, MEOX2, PAX5, PAX6, REL, ZBTB8A
# 3758                              POU6F1, THAP1, ZNF438
# 3423                                                REL
# 924                                               CREB3
# 3683                                             ZNF655
# 2109                                              MEOX2
# 373                                          ESR1, ESR2
# 1302                                               ESR1
# 3397                                           MYC, YY1
# ...                                                 ...
# 3104                                             ZBTB24
# 1539  BACH2, ZBTB24, ZNF250, ZNF275, ZNF286A, ZNF408...
# 197                                              ZNF114
# 2350                                      STAT3, ZNF587
# 258   HOXB1, MYF5, PRDM14, ZNF121, ZNF202, ZNF343, Z...
# 3766  HOXA1, PPARD, ZBTB24, ZBTB48, ZBTB8A, ZNF121, ...
# 3843                                              HOXA1
# 747                                         YY1, ZNF417
# 847                                               MEOX2
# 822                                          BCL6, OTX2
# 1572                                              TPRX1
# 1719  CDC5L, ERF, GLIS2, HOXB5, HOXC8, VEZF1, WT1, Z...
# 3435                                      NFYC, ZSCAN22
# 138   PGBD1, ZKSCAN7, ZNF24, ZNF397, ZNF446, ZNF473,...
# 687                              ZNF24, ZNF446, ZSCAN22
# 2421                     PGBD1, ZNF174, ZNF446, ZSCAN22
# 2602                                            ZKSCAN4
# 3450  ZKSCAN4, ZKSCAN7, ZNF213, ZNF24, ZNF396, ZNF44...
# 3437  PGBD1, ZGPAT, ZKSCAN4, ZKSCAN7, ZNF174, ZNF24,...
# 1426  ZKSCAN7, ZNF24, ZNF426, ZNF446, ZSCAN21, ZSCAN...
# 276                                             ZSCAN22
# 3653                                             ZNF446
# 2270                                    ZKSCAN4, ZNF446
# 812   ZKSCAN1, ZKSCAN4, ZNF24, ZNF446, ZSCAN12, ZSCA...
# 3531                                             ZBTB7B
# 3372                           ZNF446, ZSCAN22, ZSCAN23
# 264                                                JUNB
# 674                                               MSGN1
# 2970                                              ZGPAT
# 2168                                            ZNF512B
#
#       Interaction with small set of TFs
# 653                                   1
# 4150                                  1
# 3061                                  1
# 3462                                  1
# 172                                   1
# 4125                                  1
# 1933                                  1
# 1840                                  1
# 2342                                  1
# 3727                                  1
# 2717                                  1
# 212                                   1
# 1927                                  1
# 3875                                  1
# 1457                                  1
# 206                                   1
# 857                                   1
# 3937                                  1
# 1574                                  1
# 1854                                  1
# 3781                                  1
# 3071                                  1
# 3758                                  1
# 3423                                  1
# 924                                   1
# 3683                                  0
# 2109                                  1
# 373                                   1
# 1302                                  1
# 3397                                  1
# ...                                 ...
# 3104                                  1
# 1539                                  1
# 197                                   0
# 2350                                  1
# 258                                   1
# 3766                                  1
# 3843                                  1
# 747                                   1
# 847                                   1
# 822                                   1
# 1572                                  1
# 1719                                  1
# 3435                                  1
# 138                                   1
# 687                                   1
# 2421                                  1
# 2602                                  1
# 3450                                  1
# 3437                                  1
# 1426                                  1
# 276                                   1
# 3653                                  1
# 2270                                  1
# 812                                   1
# 3531                                  1
# 3372                                  1
# 264                                   1
# 674                                   1
# 2970                                  1
# 2168                                  0
#
# [4262 rows x 3 columns]
